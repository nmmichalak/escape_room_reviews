# %% [markdown]
# # Import libraries

# %%
# uncomment to install libraries
# ! pip install numpy pandas matplotlib seaborn requests selenium bs4
# ! pip install jupyter_contrib_nbextensions && jupyter contrib nbextension install 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import selenium
from bs4 import BeautifulSoup
import time

# %% [markdown]
# # Test web scraping escape room reviews

# %% [markdown]
# ## World of Escapes map page URL

# %%
map_page_url = "https://worldofescapes.com/map"

# also home page
home_page_url = "https://worldofescapes.com"

# %% [markdown]
# ## Map page response

# %%
map_page_response = requests.get(map_page_url)

# %% [markdown]
# ## Map page soup

# %%
map_page_soup = BeautifulSoup(map_page_response.text, "html.parser")

# %% [markdown]
# ## Map states and city href and URLs

# %%
# dictionary container for states and their city href and urls
state_city_href = {}
state_city_urls = {}

# loop through states and add their city href
for state_item_i in map_page_soup.find_all("div", {"class": "col-lg-3 col-md-4 col-sm-6 col-xs-6 state-item"}):
    # state str
    state_i = state_item_i.find("h3").get_text().strip().lower()
    
    # add states to href and url dictionaries
    state_city_href[state_i] = []
    state_city_urls[state_i] = []
    
    # add cities to state values
    for city_item_j in state_item_i.find_all("li", {"class": "city-item"}):
        state_city_href[state_i].append(city_item_j.a["href"])
        state_city_urls[state_i].append(home_page_url + city_item_j.a["href"])

# See URLs (which incorporate href)
state_city_urls
# Out:
# {'alabama': ['https://worldofescapes.com/auburn',
#   'https://worldofescapes.com/birm',
#   'https://worldofescapes.com/daleville',
#   'https://worldofescapes.com/dothan',
#   'https://worldofescapes.com/florence-al',
#   'https://worldofescapes.com/gadsden',
#   'https://worldofescapes.com/henagar',
#   'https://worldofescapes.com/huntsville',
#   'https://worldofescapes.com/mobile',
#   'https://worldofescapes.com/montgomery',
#   'https://worldofescapes.com/gulf-shores',
#   'https://worldofescapes.com/oxford-al',
#   'https://worldofescapes.com/tuscaloosa'],
#  'alaska': ['https://worldofescapes.com/anchorage',
#   'https://worldofescapes.com/fairbanks',
#   'https://worldofescapes.com/juneau',
#   'https://worldofescapes.com/skagway'],
#  'arizona': ['https://worldofescapes.com/cottonwood',
#   'https://worldofescapes.com/flagstaff',
#   'https://worldofescapes.com/lake-havasu-city',
#   'https://worldofescapes.com/phoenix',
#   'https://worldofescapes.com/prescott',
#   'https://worldofescapes.com/tucson',
#   'https://worldofescapes.com/yuma'],
#  'arkansas': ['https://worldofescapes.com/bentonville',
#   'https://worldofescapes.com/springdale',
#   'https://worldofescapes.com/eureka-springs',
#   'https://worldofescapes.com/fayetteville-ar',
#   'https://worldofescapes.com/fort-smith',
#   'https://worldofescapes.com/hot-springs',
#   'https://worldofescapes.com/jonesboro',
#   'https://worldofescapes.com/little-rock',
#   'https://worldofescapes.com/pine-bluff',
#   'https://worldofescapes.com/russellville',
#   'https://worldofescapes.com/searcy'],
#  'california': ['https://worldofescapes.com/bakersfield',
#   'https://worldofescapes.com/big-bear-city',
#   'https://worldofescapes.com/carlsbad',
#   'https://worldofescapes.com/chico',
#   'https://worldofescapes.com/eureka',
#   'https://worldofescapes.com/fresno',
#   'https://worldofescapes.com/grover-beach',
#   'https://worldofescapes.com/hesperia',
#   'https://worldofescapes.com/lancaster-ca',
#   'https://worldofescapes.com/livermore',
#   'https://worldofescapes.com/los-angeles',
#   'https://worldofescapes.com/modesto',
#   'https://worldofescapes.com/oceanside',
#   'https://worldofescapes.com/orange-county',
#   'https://worldofescapes.com/palm-springs',
#   'https://worldofescapes.com/pomona',
#   'https://worldofescapes.com/rancho-mirage',
#   'https://worldofescapes.com/redding',
#   'https://worldofescapes.com/redlands',
#   'https://worldofescapes.com/riverside',
#   'https://worldofescapes.com/rohnert-park',
#   'https://worldofescapes.com/sacramento',
#   'https://worldofescapes.com/salinas',
#   'https://worldofescapes.com/san-diego',
#   'https://worldofescapes.com/sfbay',
#   'https://worldofescapes.com/san-jose',
#   'https://worldofescapes.com/san-marcos-ca',
#   'https://worldofescapes.com/santa-barbara',
#   'https://worldofescapes.com/sebastopol',
#   'https://worldofescapes.com/south-lake-tahoe',
#   'https://worldofescapes.com/temecula',
#   'https://worldofescapes.com/ventura',
#   'https://worldofescapes.com/windsor-ca',
#   'https://worldofescapes.com/yuba-city'],
#  'colorado': ['https://worldofescapes.com/avon',
#   'https://worldofescapes.com/breckenridge',
#   'https://worldofescapes.com/colorado-springs',
#   'https://worldofescapes.com/denver',
#   'https://worldofescapes.com/durango',
#   'https://worldofescapes.com/fort-collins',
#   'https://worldofescapes.com/glenwood-springs',
#   'https://worldofescapes.com/grand-junction',
#   'https://worldofescapes.com/longmont',
#   'https://worldofescapes.com/pagosa-springs',
#   'https://worldofescapes.com/steamboat-springs'],
#  'connecticut': ['https://worldofescapes.com/danbury',
#   'https://worldofescapes.com/west-hartford',
#   'https://worldofescapes.com/new-haven',
#   'https://worldofescapes.com/newington',
#   'https://worldofescapes.com/norwich',
#   'https://worldofescapes.com/putnam',
#   'https://worldofescapes.com/southington',
#   'https://worldofescapes.com/stamford',
#   'https://worldofescapes.com/stonington'],
#  'delaware': ['https://worldofescapes.com/dover',
#   'https://worldofescapes.com/newark-de',
#   'https://worldofescapes.com/rehoboth-beach',
#   'https://worldofescapes.com/wilmington-de'],
#  'florida': ['https://worldofescapes.com/crystal-river',
#   'https://worldofescapes.com/daytona-beach',
#   'https://worldofescapes.com/destin',
#   'https://worldofescapes.com/fort-myers',
#   'https://worldofescapes.com/gainesville',
#   'https://worldofescapes.com/jacksonville',
#   'https://worldofescapes.com/key-largo',
#   'https://worldofescapes.com/key-west',
#   'https://worldofescapes.com/lakeland',
#   'https://worldofescapes.com/marco-island',
#   'https://worldofescapes.com/melbourne',
#   'https://worldofescapes.com/miami',
#   'https://worldofescapes.com/okeechobee',
#   'https://worldofescapes.com/orlando',
#   'https://worldofescapes.com/panama-city',
#   'https://worldofescapes.com/pensacola',
#   'https://worldofescapes.com/port-st-lucie',
#   'https://worldofescapes.com/sarasota',
#   'https://worldofescapes.com/st-augustine',
#   'https://worldofescapes.com/tallahassee',
#   'https://worldofescapes.com/tampa',
#   'https://worldofescapes.com/west-palm-beach'],
#  'georgia': ['https://worldofescapes.com/albany-ga',
#   'https://worldofescapes.com/athens',
#   'https://worldofescapes.com/atlanta',
#   'https://worldofescapes.com/augusta',
#   'https://worldofescapes.com/carrollton',
#   'https://worldofescapes.com/columbus-ga',
#   'https://worldofescapes.com/cumming',
#   'https://worldofescapes.com/dalton',
#   'https://worldofescapes.com/macon',
#   'https://worldofescapes.com/savannah',
#   'https://worldofescapes.com/valdosta'],
#  'hawaii': ['https://worldofescapes.com/hawaii',
#   'https://worldofescapes.com/honolulu',
#   'https://worldofescapes.com/kailua-kona',
#   'https://worldofescapes.com/kaneohe',
#   'https://worldofescapes.com/kauai',
#   'https://worldofescapes.com/lahaina'],
#  'idaho': ['https://worldofescapes.com/boise',
#   'https://worldofescapes.com/coeur-d-alene',
#   'https://worldofescapes.com/idaho-falls',
#   'https://worldofescapes.com/lewiston',
#   'https://worldofescapes.com/moscow',
#   'https://worldofescapes.com/pocatello',
#   'https://worldofescapes.com/post-falls',
#   'https://worldofescapes.com/rexburg',
#   'https://worldofescapes.com/twin-falls'],
#  'illinois': ['https://worldofescapes.com/bloomington',
#   'https://worldofescapes.com/bradley',
#   'https://worldofescapes.com/carbondale',
#   'https://worldofescapes.com/champaign',
#   'https://worldofescapes.com/chicago',
#   'https://worldofescapes.com/effingham',
#   'https://worldofescapes.com/elburn',
#   'https://worldofescapes.com/frankfort',
#   'https://worldofescapes.com/glen-carbon',
#   'https://worldofescapes.com/herrin',
#   'https://worldofescapes.com/naperville',
#   'https://worldofescapes.com/peoria',
#   'https://worldofescapes.com/quincy',
#   'https://worldofescapes.com/rockford',
#   'https://worldofescapes.com/springfield',
#   'https://worldofescapes.com/taylorville',
#   'https://worldofescapes.com/urbana',
#   'https://worldofescapes.com/woodstock'],
#  'indiana': ['https://worldofescapes.com/bloomington-in',
#   'https://worldofescapes.com/cedar-lake',
#   'https://worldofescapes.com/evansville',
#   'https://worldofescapes.com/fort-wayne',
#   'https://worldofescapes.com/french-lick',
#   'https://worldofescapes.com/indianapolis',
#   'https://worldofescapes.com/jeffersonville',
#   'https://worldofescapes.com/lafayette-in',
#   'https://worldofescapes.com/michigan-city',
#   'https://worldofescapes.com/muncie',
#   'https://worldofescapes.com/schererville',
#   'https://worldofescapes.com/south-bend',
#   'https://worldofescapes.com/terre-haute',
#   'https://worldofescapes.com/valparaiso',
#   'https://worldofescapes.com/vincennes',
#   'https://worldofescapes.com/wabash'],
#  'iowa': ['https://worldofescapes.com/bettendorf',
#   'https://worldofescapes.com/cedar-falls',
#   'https://worldofescapes.com/cedar-rapids',
#   'https://worldofescapes.com/clear-lake',
#   'https://worldofescapes.com/coralville',
#   'https://worldofescapes.com/dewitt',
#   'https://worldofescapes.com/des-moines',
#   'https://worldofescapes.com/dubuque',
#   'https://worldofescapes.com/okoboji',
#   'https://worldofescapes.com/sioux-city'],
#  'kansas': ['https://worldofescapes.com/bonner-springs',
#   'https://worldofescapes.com/garden-city',
#   'https://worldofescapes.com/hays',
#   'https://worldofescapes.com/hutchinson',
#   'https://worldofescapes.com/lawrence',
#   'https://worldofescapes.com/leavenworth',
#   'https://worldofescapes.com/manhattan',
#   'https://worldofescapes.com/overland-park',
#   'https://worldofescapes.com/salina',
#   'https://worldofescapes.com/topeka',
#   'https://worldofescapes.com/wichita'],
#  'kentucky': ['https://worldofescapes.com/bowling-green',
#   'https://worldofescapes.com/florence-ky',
#   'https://worldofescapes.com/glasgow-ky',
#   'https://worldofescapes.com/lexington',
#   'https://worldofescapes.com/london',
#   'https://worldofescapes.com/louisville',
#   'https://worldofescapes.com/owensboro',
#   'https://worldofescapes.com/paducah',
#   'https://worldofescapes.com/pikeville',
#   'https://worldofescapes.com/somerset'],
#  'louisiana': ['https://worldofescapes.com/alexandria',
#   'https://worldofescapes.com/baton-rouge',
#   'https://worldofescapes.com/covington',
#   'https://worldofescapes.com/houma',
#   'https://worldofescapes.com/lafayette',
#   'https://worldofescapes.com/lake-charles',
#   'https://worldofescapes.com/monroe',
#   'https://worldofescapes.com/natchitoches',
#   'https://worldofescapes.com/new-orleans',
#   'https://worldofescapes.com/ruston',
#   'https://worldofescapes.com/shreveport',
#   'https://worldofescapes.com/tickfaw'],
#  'maine': ['https://worldofescapes.com/bangor',
#   'https://worldofescapes.com/brunswick',
#   'https://worldofescapes.com/ellsworth',
#   'https://worldofescapes.com/south-portland',
#   'https://worldofescapes.com/waterville'],
#  'maryland': ['https://worldofescapes.com/annapolis',
#   'https://worldofescapes.com/baltimore',
#   'https://worldofescapes.com/bel-air',
#   'https://worldofescapes.com/california',
#   'https://worldofescapes.com/cumberland',
#   'https://worldofescapes.com/frederick',
#   'https://worldofescapes.com/gambrills',
#   'https://worldofescapes.com/grasonville',
#   'https://worldofescapes.com/ocean-city',
#   'https://worldofescapes.com/rockville',
#   'https://worldofescapes.com/salisbury'],
#  'massachusetts': ['https://worldofescapes.com/boston',
#   'https://worldofescapes.com/easthampton',
#   'https://worldofescapes.com/kingston',
#   'https://worldofescapes.com/mashpee',
#   'https://worldofescapes.com/millbury',
#   'https://worldofescapes.com/new-bedford',
#   'https://worldofescapes.com/pittsfield',
#   'https://worldofescapes.com/taunton',
#   'https://worldofescapes.com/webster',
#   'https://worldofescapes.com/winchendon',
#   'https://worldofescapes.com/worcester'],
#  'michigan': ['https://worldofescapes.com/ann-arbor',
#   'https://worldofescapes.com/battle-creek',
#   'https://worldofescapes.com/brighton-mi',
#   'https://worldofescapes.com/clinton',
#   'https://worldofescapes.com/davison',
#   'https://worldofescapes.com/detroit',
#   'https://worldofescapes.com/flint',
#   'https://worldofescapes.com/gaylord',
#   'https://worldofescapes.com/grand-haven',
#   'https://worldofescapes.com/grand-rapids',
#   'https://worldofescapes.com/grayling',
#   'https://worldofescapes.com/hart',
#   'https://worldofescapes.com/imlay-city',
#   'https://worldofescapes.com/jackson-mi',
#   'https://worldofescapes.com/lansing',
#   'https://worldofescapes.com/mackinaw-city',
#   'https://worldofescapes.com/marquette',
#   'https://worldofescapes.com/midland',
#   'https://worldofescapes.com/monroe-mi',
#   'https://worldofescapes.com/mt-pleasant',
#   'https://worldofescapes.com/muskegon',
#   'https://worldofescapes.com/onsted',
#   'https://worldofescapes.com/petoskey',
#   'https://worldofescapes.com/port-huron',
#   'https://worldofescapes.com/portage',
#   'https://worldofescapes.com/bay-city',
#   'https://worldofescapes.com/st-joseph-mi',
#   'https://worldofescapes.com/traverse-city',
#   'https://worldofescapes.com/zeeland'],
#  'minnesota': ['https://worldofescapes.com/alexandria-mn',
#   'https://worldofescapes.com/bemidji',
#   'https://worldofescapes.com/brainerd',
#   'https://worldofescapes.com/duluth',
#   'https://worldofescapes.com/mankato',
#   'https://worldofescapes.com/minneapolis',
#   'https://worldofescapes.com/park-rapids',
#   'https://worldofescapes.com/rochester-mn',
#   'https://worldofescapes.com/roseau',
#   'https://worldofescapes.com/st-cloud',
#   'https://worldofescapes.com/winona'],
#  'mississippi': ['https://worldofescapes.com/biloxi',
#   'https://worldofescapes.com/corinth',
#   'https://worldofescapes.com/hattiesburg',
#   'https://worldofescapes.com/jackson-ms',
#   'https://worldofescapes.com/oxford-ms',
#   'https://worldofescapes.com/picayune',
#   'https://worldofescapes.com/starkville',
#   'https://worldofescapes.com/tupelo'],
#  'missouri': ['https://worldofescapes.com/branson',
#   'https://worldofescapes.com/cape-girardeau',
#   'https://worldofescapes.com/columbia-mo',
#   'https://worldofescapes.com/hannibal',
#   'https://worldofescapes.com/jefferson-city',
#   'https://worldofescapes.com/joplin',
#   'https://worldofescapes.com/kansas-city',
#   'https://worldofescapes.com/kirksville',
#   'https://worldofescapes.com/lake-ozark',
#   'https://worldofescapes.com/maryville',
#   'https://worldofescapes.com/springfield-mo',
#   'https://worldofescapes.com/st-joseph-mo',
#   'https://worldofescapes.com/st-louis',
#   'https://worldofescapes.com/west-plains',
#   'https://worldofescapes.com/windsor'],
#  'montana': ['https://worldofescapes.com/belgrade',
#   'https://worldofescapes.com/billings',
#   'https://worldofescapes.com/bozeman',
#   'https://worldofescapes.com/butte',
#   'https://worldofescapes.com/great-falls',
#   'https://worldofescapes.com/helena',
#   'https://worldofescapes.com/missoula',
#   'https://worldofescapes.com/whitefish'],
#  'nebraska': ['https://worldofescapes.com/aurora',
#   'https://worldofescapes.com/columbus-ne',
#   'https://worldofescapes.com/hastings',
#   'https://worldofescapes.com/kearney',
#   'https://worldofescapes.com/lincoln',
#   'https://worldofescapes.com/omaha'],
#  'nevada': ['https://worldofescapes.com/las-vegas',
#   'https://worldofescapes.com/reno'],
#  'new hampshire': ['https://worldofescapes.com/amherst',
#   'https://worldofescapes.com/claremont',
#   'https://worldofescapes.com/concord',
#   'https://worldofescapes.com/derry',
#   'https://worldofescapes.com/laconia',
#   'https://worldofescapes.com/littleton',
#   'https://worldofescapes.com/manchester',
#   'https://worldofescapes.com/nashua',
#   'https://worldofescapes.com/newbury',
#   'https://worldofescapes.com/north-conway',
#   'https://worldofescapes.com/portsmouth'],
#  'new jersey': ['https://worldofescapes.com/andover',
#   'https://worldofescapes.com/atlantic-city',
#   'https://worldofescapes.com/bridgewater',
#   'https://worldofescapes.com/rio-grande',
#   'https://worldofescapes.com/collingswood',
#   'https://worldofescapes.com/flemington',
#   'https://worldofescapes.com/freehold',
#   'https://worldofescapes.com/garwood',
#   'https://worldofescapes.com/glassboro',
#   'https://worldofescapes.com/long-branch',
#   'https://worldofescapes.com/millville',
#   'https://worldofescapes.com/new-brunswick',
#   'https://worldofescapes.com/princeton',
#   'https://worldofescapes.com/toms-river',
#   'https://worldofescapes.com/vernon'],
#  'new mexico': ['https://worldofescapes.com/albuquerque',
#   'https://worldofescapes.com/aztec',
#   'https://worldofescapes.com/clovis',
#   'https://worldofescapes.com/las-cruces',
#   'https://worldofescapes.com/roswell',
#   'https://worldofescapes.com/ruidoso',
#   'https://worldofescapes.com/santa-fe'],
#  'new york': ['https://worldofescapes.com/albany',
#   'https://worldofescapes.com/auburn-ny',
#   'https://worldofescapes.com/batavia',
#   'https://worldofescapes.com/binghamton',
#   'https://worldofescapes.com/buffalo',
#   'https://worldofescapes.com/cooperstown',
#   'https://worldofescapes.com/fulton',
#   'https://worldofescapes.com/horseheads',
#   'https://worldofescapes.com/ithaca',
#   'https://worldofescapes.com/nyc',
#   'https://worldofescapes.com/newburgh',
#   'https://worldofescapes.com/nyack',
#   'https://worldofescapes.com/riverhead',
#   'https://worldofescapes.com/rochester',
#   'https://worldofescapes.com/swain',
#   'https://worldofescapes.com/syracuse',
#   'https://worldofescapes.com/ulster-park',
#   'https://worldofescapes.com/watertown',
#   'https://worldofescapes.com/white-plains',
#   'https://worldofescapes.com/yorktown'],
#  'north carolina': ['https://worldofescapes.com/archdale',
#   'https://worldofescapes.com/asheville',
#   'https://worldofescapes.com/beaufort-nc',
#   'https://worldofescapes.com/boone',
#   'https://worldofescapes.com/cameron',
#   'https://worldofescapes.com/charlotte',
#   'https://worldofescapes.com/fayetteville',
#   'https://worldofescapes.com/goldsboro',
#   'https://worldofescapes.com/greensboro',
#   'https://worldofescapes.com/greenville-nc',
#   'https://worldofescapes.com/hudson',
#   'https://worldofescapes.com/jacksonville-nc',
#   'https://worldofescapes.com/maggie-valley',
#   'https://worldofescapes.com/mebane',
#   'https://worldofescapes.com/mooresville',
#   'https://worldofescapes.com/morrisville',
#   'https://worldofescapes.com/new-bern',
#   'https://worldofescapes.com/raleigh',
#   'https://worldofescapes.com/shelby',
#   'https://worldofescapes.com/smithfield',
#   'https://worldofescapes.com/southern-pines',
#   'https://worldofescapes.com/southern-shores',
#   'https://worldofescapes.com/statesville',
#   'https://worldofescapes.com/sylva',
#   'https://worldofescapes.com/wilmington',
#   'https://worldofescapes.com/winston-salem'],
#  'north dakota': ['https://worldofescapes.com/bismarck',
#   'https://worldofescapes.com/west-fargo',
#   'https://worldofescapes.com/grand-forks',
#   'https://worldofescapes.com/minot',
#   'https://worldofescapes.com/williston'],
#  'ohio': ['https://worldofescapes.com/akron',
#   'https://worldofescapes.com/ashtabula',
#   'https://worldofescapes.com/bellaire',
#   'https://worldofescapes.com/canton',
#   'https://worldofescapes.com/cincinnati',
#   'https://worldofescapes.com/cleveland',
#   'https://worldofescapes.com/columbus',
#   'https://worldofescapes.com/dayton',
#   'https://worldofescapes.com/findlay',
#   'https://worldofescapes.com/mansfield',
#   'https://worldofescapes.com/portsmouth-oh',
#   'https://worldofescapes.com/sandusky',
#   'https://worldofescapes.com/toledo',
#   'https://worldofescapes.com/wapakoneta',
#   'https://worldofescapes.com/warren-oh'],
#  'oklahoma': ['https://worldofescapes.com/broken-bow',
#   'https://worldofescapes.com/durant',
#   'https://worldofescapes.com/lawton',
#   'https://worldofescapes.com/muldrow',
#   'https://worldofescapes.com/oklahoma-city',
#   'https://worldofescapes.com/tulsa'],
#  'oregon': ['https://worldofescapes.com/bend',
#   'https://worldofescapes.com/cannon-beach',
#   'https://worldofescapes.com/eugene',
#   'https://worldofescapes.com/hood-river',
#   'https://worldofescapes.com/la-grande',
#   'https://worldofescapes.com/medford',
#   'https://worldofescapes.com/newport',
#   'https://worldofescapes.com/portland',
#   'https://worldofescapes.com/salem'],
#  'pennsylvania': ['https://worldofescapes.com/annville',
#   'https://worldofescapes.com/bartonsville',
#   'https://worldofescapes.com/bethlehem',
#   'https://worldofescapes.com/erie',
#   'https://worldofescapes.com/gettysburg',
#   'https://worldofescapes.com/hershey',
#   'https://worldofescapes.com/king-of-prussia',
#   'https://worldofescapes.com/lancaster',
#   'https://worldofescapes.com/lewisburg',
#   'https://worldofescapes.com/montgomeryville',
#   'https://worldofescapes.com/philly',
#   'https://worldofescapes.com/pittsburgh',
#   'https://worldofescapes.com/scranton',
#   'https://worldofescapes.com/sinking-spring',
#   'https://worldofescapes.com/slippery-rock',
#   'https://worldofescapes.com/stevens',
#   'https://worldofescapes.com/titusville',
#   'https://worldofescapes.com/trappe',
#   'https://worldofescapes.com/wyomissing',
#   'https://worldofescapes.com/york'],
#  'rhode island': ['https://worldofescapes.com/providence'],
#  'south carolina': ['https://worldofescapes.com/aiken',
#   'https://worldofescapes.com/beaufort',
#   'https://worldofescapes.com/charleston',
#   'https://worldofescapes.com/columbia',
#   'https://worldofescapes.com/florence-sc',
#   'https://worldofescapes.com/gaffney',
#   'https://worldofescapes.com/greenville',
#   'https://worldofescapes.com/hilton-head',
#   'https://worldofescapes.com/myrtle-beach',
#   'https://worldofescapes.com/rock-hill'],
#  'south dakota': ['https://worldofescapes.com/rapid-city',
#   'https://worldofescapes.com/sioux-falls'],
#  'tennessee': ['https://worldofescapes.com/chattanooga',
#   'https://worldofescapes.com/clarksville',
#   'https://worldofescapes.com/jacksoj',
#   'https://worldofescapes.com/kingsport',
#   'https://worldofescapes.com/knoxville',
#   'https://worldofescapes.com/memphis',
#   'https://worldofescapes.com/murfreesboro',
#   'https://worldofescapes.com/nashville',
#   'https://worldofescapes.com/pigeon-forge'],
#  'texas': ['https://worldofescapes.com/amarillo',
#   'https://worldofescapes.com/arlington-tx',
#   'https://worldofescapes.com/austin',
#   'https://worldofescapes.com/college-station',
#   'https://worldofescapes.com/corpus-christi',
#   'https://worldofescapes.com/dallas',
#   'https://worldofescapes.com/denton',
#   'https://worldofescapes.com/el-paso',
#   'https://worldofescapes.com/fredericksburg-tx',
#   'https://worldofescapes.com/harlingen',
#   'https://worldofescapes.com/houston',
#   'https://worldofescapes.com/killeen',
#   'https://worldofescapes.com/lubbock',
#   'https://worldofescapes.com/marathon',
#   'https://worldofescapes.com/mckinney',
#   'https://worldofescapes.com/san-antonio',
#   'https://worldofescapes.com/san-marcos',
#   'https://worldofescapes.com/sherman',
#   'https://worldofescapes.com/tyler',
#   'https://worldofescapes.com/victoria',
#   'https://worldofescapes.com/waco'],
#  'utah': ['https://worldofescapes.com/cedar-city',
#   'https://worldofescapes.com/ogden',
#   'https://worldofescapes.com/provo',
#   'https://worldofescapes.com/slc',
#   'https://worldofescapes.com/st-george'],
#  'vermont': ['https://worldofescapes.com/burlington',
#   'https://worldofescapes.com/dover-vt',
#   'https://worldofescapes.com/stowe'],
#  'virginia': ['https://worldofescapes.com/arlington-va',
#   'https://worldofescapes.com/charlottesville',
#   'https://worldofescapes.com/fredericksburg',
#   'https://worldofescapes.com/harrisonburg',
#   'https://worldofescapes.com/lynchburg',
#   'https://worldofescapes.com/newport-news',
#   'https://worldofescapes.com/richmond-v-a',
#   'https://worldofescapes.com/roanoke',
#   'https://worldofescapes.com/virginia-beach',
#   'https://worldofescapes.com/warrenton',
#   'https://worldofescapes.com/williamsburg'],
#  'washington': ['https://worldofescapes.com/gig-harbor',
#   'https://worldofescapes.com/marysville',
#   'https://worldofescapes.com/seattle',
#   'https://worldofescapes.com/spokane',
#   'https://worldofescapes.com/tacoma',
#   'https://worldofescapes.com/wenatchee'],
#  'west virginia': ['https://worldofescapes.com/charleston-wv',
#   'https://worldofescapes.com/fayetteville-wv',
#   'https://worldofescapes.com/huntington',
#   'https://worldofescapes.com/morgantown',
#   'https://worldofescapes.com/parkersburg',
#   'https://worldofescapes.com/princeton-wv',
#   'https://worldofescapes.com/weirton'],
#  'wisconsin': ['https://worldofescapes.com/appleton',
#   'https://worldofescapes.com/eau-claire',
#   'https://worldofescapes.com/green-bay',
#   'https://worldofescapes.com/la-crosse',
#   'https://worldofescapes.com/lake-geneva',
#   'https://worldofescapes.com/madison',
#   'https://worldofescapes.com/manitowoc',
#   'https://worldofescapes.com/milwaukee',
#   'https://worldofescapes.com/minocqua',
#   'https://worldofescapes.com/oshkosh',
#   'https://worldofescapes.com/wausau',
#   'https://worldofescapes.com/wisconsin-dells'],
#  'wyoming': ['https://worldofescapes.com/casper',
#   'https://worldofescapes.com/cheyenne',
#   'https://worldofescapes.com/cody',
#   'https://worldofescapes.com/evanston',
#   'https://worldofescapes.com/gillette',
#   'https://worldofescapes.com/rock-springs',
#   'https://worldofescapes.com/sheridan']}

# %% [markdown]
# ## Map states and city page responses and soups

# %%
# containers for state and their city page responses and soups
state_city_responses = {}
state_city_soups = {}

# loop through responses and soups
# just alabama and michigan for now
for state_key, city_url in {state: state_city_urls[state] for state in ("alabama", "michigan")}.items():
    # add state key to dictionary containers
    state_city_responses[state_key] = []
    state_city_soups[state_key] = []
    
    for url in city_url:
        # get response
        response_j = requests.get(url)
        
        # make soup
        soup_j = BeautifulSoup(response_j.text, "html.parser")
        
        # append response and soup to state
        state_city_responses[state_key].append(response_j)
        state_city_soups[state_key].append(soup_j)
        
        # sleep for a random number of seconds
        sleep_time_j = np.random.randint(low = 1, high = 5, size = 1)
        time.sleep(sleep_time_j)
        
        # print loop summary
        print("Made soup for {} in {}. Sleeping for {} seconds...".format(url, state_key, sleep_time_j))
# Out:
# Made soup for https://worldofescapes.com/auburn in alabama. Sleeping for [4] seconds...
# Made soup for https://worldofescapes.com/birm in alabama. Sleeping for [2] seconds...
# Made soup for https://worldofescapes.com/daleville in alabama. Sleeping for [2] seconds...
# Made soup for https://worldofescapes.com/dothan in alabama. Sleeping for [4] seconds...
# Made soup for https://worldofescapes.com/florence-al in alabama. Sleeping for [4] seconds...
# Made soup for https://worldofescapes.com/gadsden in alabama. Sleeping for [4] seconds...
# Made soup for https://worldofescapes.com/henagar in alabama. Sleeping for [3] seconds...
# Made soup for https://worldofescapes.com/huntsville in alabama. Sleeping for [3] seconds...
# Made soup for https://worldofescapes.com/mobile in alabama. Sleeping for [2] seconds...
# Made soup for https://worldofescapes.com/montgomery in alabama. Sleeping for [4] seconds...
# Made soup for https://worldofescapes.com/gulf-shores in alabama. Sleeping for [1] seconds...
# Made soup for https://worldofescapes.com/oxford-al in alabama. Sleeping for [1] seconds...
# Made soup for https://worldofescapes.com/tuscaloosa in alabama. Sleeping for [2] seconds...
# Made soup for https://worldofescapes.com/ann-arbor in michigan. Sleeping for [4] seconds...
# Made soup for https://worldofescapes.com/battle-creek in michigan. Sleeping for [1] seconds...
# Made soup for https://worldofescapes.com/brighton-mi in michigan. Sleeping for [3] seconds...
# Made soup for https://worldofescapes.com/clinton in michigan. Sleeping for [1] seconds...
# Made soup for https://worldofescapes.com/davison in michigan. Sleeping for [1] seconds...
# Made soup for https://worldofescapes.com/detroit in michigan. Sleeping for [2] seconds...
# Made soup for https://worldofescapes.com/flint in michigan. Sleeping for [2] seconds...
# Made soup for https://worldofescapes.com/gaylord in michigan. Sleeping for [4] seconds...
# Made soup for https://worldofescapes.com/grand-haven in michigan. Sleeping for [3] seconds...
# Made soup for https://worldofescapes.com/grand-rapids in michigan. Sleeping for [4] seconds...
# Made soup for https://worldofescapes.com/grayling in michigan. Sleeping for [4] seconds...
# Made soup for https://worldofescapes.com/hart in michigan. Sleeping for [2] seconds...
# Made soup for https://worldofescapes.com/imlay-city in michigan. Sleeping for [2] seconds...
# Made soup for https://worldofescapes.com/jackson-mi in michigan. Sleeping for [3] seconds...
# Made soup for https://worldofescapes.com/lansing in michigan. Sleeping for [4] seconds...
# Made soup for https://worldofescapes.com/mackinaw-city in michigan. Sleeping for [4] seconds...
# Made soup for https://worldofescapes.com/marquette in michigan. Sleeping for [1] seconds...
# Made soup for https://worldofescapes.com/midland in michigan. Sleeping for [3] seconds...
# Made soup for https://worldofescapes.com/monroe-mi in michigan. Sleeping for [4] seconds...
# Made soup for https://worldofescapes.com/mt-pleasant in michigan. Sleeping for [3] seconds...
# Made soup for https://worldofescapes.com/muskegon in michigan. Sleeping for [3] seconds...
# Made soup for https://worldofescapes.com/onsted in michigan. Sleeping for [3] seconds...
# Made soup for https://worldofescapes.com/petoskey in michigan. Sleeping for [4] seconds...
# Made soup for https://worldofescapes.com/port-huron in michigan. Sleeping for [2] seconds...
# Made soup for https://worldofescapes.com/portage in michigan. Sleeping for [4] seconds...
# Made soup for https://worldofescapes.com/bay-city in michigan. Sleeping for [1] seconds...
# Made soup for https://worldofescapes.com/st-joseph-mi in michigan. Sleeping for [1] seconds...
# Made soup for https://worldofescapes.com/traverse-city in michigan. Sleeping for [3] seconds...
# Made soup for https://worldofescapes.com/zeeland in michigan. Sleeping for [3] seconds...

# %% [markdown]
# ## Escape room href and URLs

# %%
for a in state_city_soups["alabama"][0].find("div", {"data-content": "other-quests"}).find_all("a", {"class": "item-hover quest_tile_hover_link"}):
    print(a["href"])
# Out:
# /auburn/quests/auburn-escape-zones-the-cabin
# /auburn/quests/auburn-escape-zones-imprisoned
# /auburn/quests/auburn-escape-zones-the-puzzler-vs-superheroes
# /auburn/quests/auburn-escape-zones-vault
# /auburn/quests/auburn-escape-zones-black-beards-brig

# %%
state_city_soups["michigan"][3].find("div", {"data-content": "other-quests"})

# %%
# containers for state and their city page responses and soups
state_city_room_urls = {}

# loop through responses and soups
# just alabama and michigan for now
for state_key, city_soup in {state: state_city_soups[state] for state in ("alabama", "michigan")}.items():
    # add state key to dictionary containers
    state_city_room_urls[state_key] = {}

    for j, soup in enumerate(city_soup):
        # add dictionary container to each city href value
        # nested dictionaries, e.g., {"alabama": "/auburn": [NEW escape room href go here, ...]}
        state_city_room_urls[state_key][state_city_href[state_key][j]] = []
        
        # loop through a tags with escape room href
        
        if soup.find("div", {"data-content": "other-quests"}) is not None:
            for a in soup.find("div", {"data-content": "other-quests"}).find_all("a", {"class": "item-hover quest_tile_hover_link"}):
                
                # add href
                state_city_room_urls[state_key][state_city_href[state_key][j]].append(a["href"])
                
                # print loop summary
                print("Added href {} for {} in {}.".format(a["href"], state_city_href[state_key][j], state_key))
                
        else:
            print("None")
# Out:
# Added href /auburn/quests/auburn-escape-zones-the-cabin for /auburn in alabama.
# Added href /auburn/quests/auburn-escape-zones-imprisoned for /auburn in alabama.
# Added href /auburn/quests/auburn-escape-zones-the-puzzler-vs-superheroes for /auburn in alabama.
# Added href /auburn/quests/auburn-escape-zones-vault for /auburn in alabama.
# Added href /auburn/quests/auburn-escape-zones-black-beards-brig for /auburn in alabama.
# Added href /birm/quests/Locked-In-THE-LABORATORY for /birm in alabama.
# Added href /birm/quests/locked-in-birm-the-classroom for /birm in alabama.
# Added href /birm/quests/Locked-In-THE-WAREHOUSE for /birm in alabama.
# Added href /birm/quests/nightmare-at-3008-3008-house for /birm in alabama.
# Added href /birm/quests/nightmare-at-3008-camp-mary-lee for /birm in alabama.
# Added href /birm/quests/nightmare-at-3008-the-underground for /birm in alabama.
# Added href /birm/quests/train-escape-sabotage for /birm in alabama.
# Added href /birm/quests/train-escape-classified for /birm in alabama.
# Added href /birm/quests/Locked-In-THE-MUSEUM for /birm in alabama.
# Added href /daleville/quests/brain-busters-escape-rooms-the-grove for /daleville in alabama.
# Added href /daleville/quests/brain-busters-escape-rooms-booty-battle for /daleville in alabama.
# Added href /daleville/quests/brain-busters-escape-rooms-out-of-order for /daleville in alabama.
# Added href /daleville/quests/brain-busters-escape-rooms-wizard-quest for /daleville in alabama.
# Added href /daleville/quests/brain-busters-escape-rooms-bio-lab for /daleville in alabama.
# Added href /daleville/quests/escape-enterprise-the-box for /daleville in alabama.
# Added href /daleville/quests/escape-enterprise-the-secret-society for /daleville in alabama.
# Added href /daleville/quests/escape-enterprise-the-shack for /daleville in alabama.
# Added href /dothan/quests/escape-dothan-the-13th-floor for /dothan in alabama.
# Added href /dothan/quests/escape-dothan-murder-at-the-mansion for /dothan in alabama.
# Added href /dothan/quests/escape-dothan-time-warp for /dothan in alabama.
# Added href /dothan/quests/escape-dothan-bazaar-battle for /dothan in alabama.
# Added href /florence-al/quests/escape-room-florence-lost-cabin for /florence-al in alabama.
# Added href /florence-al/quests/escape-room-florence-espionage for /florence-al in alabama.
# Added href /florence-al/quests/escape-room-florence-sound-escape for /florence-al in alabama.
# Added href /florence-al/quests/escape-room-florence-bio-hazard-bunker for /florence-al in alabama.
# Added href /gadsden/quests/beat60-the-darkness for /gadsden in alabama.
# Added href /gadsden/quests/beat60-the-captain for /gadsden in alabama.
# Added href /gadsden/quests/beat60-jewel-thief for /gadsden in alabama.
# Added href /henagar/quests/escape-room-adventures-zombie-escape for /henagar in alabama.
# Added href /henagar/quests/escape-room-adventures-dash-for-the-cash for /henagar in alabama.
# Added href /huntsville/quests/huntsville-escape-rooms-the-hexadron for /huntsville in alabama.
# Added href /huntsville/quests/Huntsville-Escape-Rooms-The-Psyche-Ward for /huntsville in alabama.
# Added href /huntsville/quests/Huntsville-Escape-Rooms-The-Informant for /huntsville in alabama.
# Added href /huntsville/quests/huntsville-escape-rooms-the-queen-pin for /huntsville in alabama.
# Added href /huntsville/quests/huntsville-escape-rooms-the-new-atlantis for /huntsville in alabama.
# Added href /huntsville/quests/escapology-huntsville-budapest-express for /huntsville in alabama.
# Added href /huntsville/quests/huntsville-escape-rooms-the-executioner for /huntsville in alabama.
# Added href /huntsville/quests/escapology-huntsville-antidote for /huntsville in alabama.
# Added href /huntsville/quests/escapology-huntsville-under-pressure for /huntsville in alabama.
# Added href /huntsville/quests/trapped-in-decatur-escape-from-alcatraz for /huntsville in alabama.
# Added href /huntsville/quests/trapped-in-decatur-the-bank-robbery for /huntsville in alabama.
# Added href /huntsville/quests/trapped-in-decatur-treasure-of-the-emerald-isles for /huntsville in alabama.
# Added href /huntsville/quests/trapped-in-decatur-the-morgue-of-dr-g-reaper for /huntsville in alabama.
# Added href /mobile/quests/fairhope-escape-rooms-night-bandit-treasure for /mobile in alabama.
# Added href /montgomery/quests/escapology-montgomery-antidote for /montgomery in alabama.
# Added href /montgomery/quests/escapology-montgomery-cuban-crisis for /montgomery in alabama.
# Added href /montgomery/quests/escapology-montgomery-budapest-express for /montgomery in alabama.
# Added href /montgomery/quests/escapology-montgomery-arizona-shootout for /montgomery in alabama.
# Added href /montgomery/quests/escapology-montgomery-shanghaied for /montgomery in alabama.
# Added href /montgomery/quests/escapology-montgomery-the-code for /montgomery in alabama.
# Added href /montgomery/quests/breakout-montgomery-hostage for /montgomery in alabama.
# Added href /montgomery/quests/breakout-montgomery-the-kidnapping for /montgomery in alabama.
# Added href /montgomery/quests/breakout-montgomery-museum-heist for /montgomery in alabama.
# Added href /montgomery/quests/breakout-games-montgomery-mystery-mansion for /montgomery in alabama.
# Added href /montgomery/quests/breakout-montgomery-operation-casino for /montgomery in alabama.
# Added href /gulf-shores/quests/get-a-clue-crime-scene for /gulf-shores in alabama.
# Added href /gulf-shores/quests/Gulf-Coast-Escape-Room-THE-DOLL-ROOM for /gulf-shores in alabama.
# Added href /gulf-shores/quests/get-a-clue-mardi-gras for /gulf-shores in alabama.
# Added href /gulf-shores/quests/escape-house-waterville-the-room-of-the-great-mysto for /gulf-shores in alabama.
# Added href /gulf-shores/quests/xit-escape-room-insane-asylum for /gulf-shores in alabama.
# Added href /gulf-shores/quests/Gulf-Coast-Escape-Room-ZOMBIE-LAB for /gulf-shores in alabama.
# Added href /gulf-shores/quests/xit-escape-room-csi-gulf-shores for /gulf-shores in alabama.
# Added href /gulf-shores/quests/gulf-coast-escape-room-bates-motel for /gulf-shores in alabama.
# Added href /gulf-shores/quests/get-a-clue-paranormal-investigation for /gulf-shores in alabama.
# Added href /gulf-shores/quests/xit-escape-room-a-tale-of-two-forts for /gulf-shores in alabama.
# Added href /gulf-shores/quests/xit-escape-room-movie-night for /gulf-shores in alabama.
# Added href /gulf-shores/quests/escape-house-waterville-the-hurricane-room for /gulf-shores in alabama.
# Added href /gulf-shores/quests/gulf-coast-escape-room-gs-voodoo-cabin for /gulf-shores in alabama.
# Added href /oxford-al/quests/escape-zone-oxford-the-golden-formula for /oxford-al in alabama.
# Added href /oxford-al/quests/escape-zone-oxford-the-bank-heist for /oxford-al in alabama.
# Added href /oxford-al/quests/escape-zone-oxford-sulleys-sinking-ship for /oxford-al in alabama.
# Added href /tuscaloosa/quests/Horror-Hotel for /tuscaloosa in alabama.
# Added href /tuscaloosa/quests/escape-tuscaloosa-the-cabin for /tuscaloosa in alabama.
# Added href /tuscaloosa/quests/escape-tuscaloosa-the-prison for /tuscaloosa in alabama.
# Added href /tuscaloosa/quests/escape-tuscaloosa-the-playbook for /tuscaloosa in alabama.
# Added href /tuscaloosa/quests/breakout-tuscaloosa-derailed for /tuscaloosa in alabama.
# Added href /tuscaloosa/quests/breakout-tuscaloosa-the-mission for /tuscaloosa in alabama.
# Added href /tuscaloosa/quests/escape-tuscaloosa-the-haunted for /tuscaloosa in alabama.
# Added href /tuscaloosa/quests/escape-tuscaloosa-abducted for /tuscaloosa in alabama.
# Added href /tuscaloosa/quests/all-in-adventures-escape-from-alcatraz for /tuscaloosa in alabama.
# Added href /tuscaloosa/quests/all-in-adventures-treasure-island for /tuscaloosa in alabama.
# Added href /tuscaloosa/quests/all-in-adventures-sherlocks-library for /tuscaloosa in alabama.
# Added href /ann-arbor/quests/decode-detroit-the-minerva-project for /ann-arbor in michigan.
# Added href /ann-arbor/quests/breakout-escape-rooms-ann-arbor-zombie-roadhouse for /ann-arbor in michigan.
# Added href /ann-arbor/quests/clueless-escape-rooms-save-tony for /ann-arbor in michigan.
# Added href /ann-arbor/quests/breakout-escape-rooms-ann-arbor-game-of-espionage for /ann-arbor in michigan.
# Added href /ann-arbor/quests/decode-detroit-minervas-return for /ann-arbor in michigan.
# Added href /ann-arbor/quests/breakout-escape-rooms-ann-arbor-the-ringmasters-den for /ann-arbor in michigan.
# Added href /ann-arbor/quests/breakout-escape-rooms-ann-arbor-chamber-of-illusions for /ann-arbor in michigan.
# Added href /ann-arbor/quests/clueless-escape-rooms-candy-caper for /ann-arbor in michigan.
# Added href /ann-arbor/quests/decode-escape-room-the-minerva-project for /ann-arbor in michigan.
# Added href /ann-arbor/quests/clueless-escape-rooms-castaway-island for /ann-arbor in michigan.
# Added href /ann-arbor/quests/clueless--escape-rooms-corporate-escape for /ann-arbor in michigan.
# Added href /ann-arbor/quests/clueless-escape-rooms-football-fury for /ann-arbor in michigan.
# Added href /battle-creek/quests/break-escape-the-cabin for /battle-creek in michigan.
# Added href /battle-creek/quests/break-escape-the-library for /battle-creek in michigan.
# Added href /brighton-mi/quests/puzzled-escape-surviving-the-apocalypse for /brighton-mi in michigan.
# Added href /brighton-mi/quests/puzzled-escape-the-laboratory for /brighton-mi in michigan.
# Added href /brighton-mi/quests/puzzled-escape-patient-37 for /brighton-mi in michigan.
# None
# Added href /davison/quests/michigan-escape-games-mission-impossibly for /davison in michigan.
# Added href /davison/quests/michigan-escape-games-csl-homicide-detectives for /davison in michigan.
# Added href /davison/quests/michigan-escape-games-viral-containment-cdc-labs for /davison in michigan.
# Added href /davison/quests/michigan-escape-games-the-heist for /davison in michigan.
# Added href /davison/quests/Michiga-Escape-Games-CheckMate for /davison in michigan.
# Added href /davison/quests/michigan-escape-games-the-dwelling for /davison in michigan.
# Added href /davison/quests/michigan-escape-games-the-steampunk-time-machine for /davison in michigan.
# Added href /davison/quests/michigan-escape-games-blackout for /davison in michigan.
# Added href /davison/quests/michigan-escape-games-meltdown for /davison in michigan.
# Added href /davison/quests/michigan-escape-games-final-breath for /davison in michigan.
# Added href /detroit/quests/erebus-escape-lockdown for /detroit in michigan.
# Added href /detroit/quests/xtreme-escape-rooms-patient-zero for /detroit in michigan.
# Added href /detroit/quests/escape-the-post-zombie-apocalypse for /detroit in michigan.
# Added href /detroit/quests/michigan-escape-room-the-elevator for /detroit in michigan.
# Added href /detroit/quests/descape-mission-mission-motown for /detroit in michigan.
# Added href /detroit/quests/Breakout-The-Room-Escape-Game-Zombie-Roadhouse-W for /detroit in michigan.
# Added href /detroit/quests/xtreme-escape-rooms-time-bomb for /detroit in michigan.
# Added href /detroit/quests/escape-the-room-detroit-the-dig for /detroit in michigan.
# Added href /detroit/quests/ideal-escape-rooms-escape-the-wild-west for /detroit in michigan.
# Added href /detroit/quests/escape-room-novi-the-illusionist for /detroit in michigan.
# Added href /detroit/quests/excape-games-murder-mystery for /detroit in michigan.
# Added href /detroit/quests/Breakout-The-Room-Escape-Game-The-Ringmasters-Den-W for /detroit in michigan.
# Added href /detroit/quests/escape-the-post-the-cell for /detroit in michigan.
# Added href /detroit/quests/escape-room-novi-tonys-bistro for /detroit in michigan.
# Added href /detroit/quests/escape-room-novi-pirates-of-the-seas for /detroit in michigan.
# Added href /detroit/quests/rush2escape-bank-heist-gone-wrong for /detroit in michigan.
# Added href /detroit/quests/the-great-escape-room-the-library-sherlocks-study for /detroit in michigan.
# Added href /detroit/quests/escape-the-post-the-bistro for /detroit in michigan.
# Added href /detroit/quests/excape-games-jail-break for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-bank-heist for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-mad-scientist for /detroit in michigan.
# Added href /detroit/quests/michigan-escape-room-kidnapped-in-the-warehouse for /detroit in michigan.
# Added href /detroit/quests/excape-games-abandon-ship for /detroit in michigan.
# Added href /detroit/quests/michigan-escape-room-saloon for /detroit in michigan.
# Added href /detroit/quests/ecsape-room-zone-prison-break for /detroit in michigan.
# Added href /detroit/quests/michigan-escape-room-misfortune for /detroit in michigan.
# Added href /detroit/quests/escape-room-studios-steampunk-gypsies for /detroit in michigan.
# Added href /detroit/quests/the-great-escape-room-the-infirmary for /detroit in michigan.
# Added href /detroit/quests/the-great-escape-room-royal-oak-the-presidents-bunker for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-pharaohs-curse for /detroit in michigan.
# Added href /detroit/quests/time-2-xcape-crack-the-case for /detroit in michigan.
# Added href /detroit/quests/escape-the-post-find-teddy for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-pirates-curse for /detroit in michigan.
# Added href /detroit/quests/escape-the-post-the-sheriffs-office for /detroit in michigan.
# Added href /detroit/quests/think-it-out-superhero-university for /detroit in michigan.
# Added href /detroit/quests/clever-clues-escape-room-the-precinct for /detroit in michigan.
# Added href /detroit/quests/clever-clues-escape-room-the-meltdown for /detroit in michigan.
# Added href /detroit/quests/escape-the-room-detroit-the-rec-room for /detroit in michigan.
# Added href /detroit/quests/escape-room-novi-the-speakeasy for /detroit in michigan.
# Added href /detroit/quests/escape-the-room-detroit-agency for /detroit in michigan.
# Added href /detroit/quests/ideal-escape-rooms-firefighter-rescue for /detroit in michigan.
# Added href /detroit/quests/time-2-xcape-crash-landing for /detroit in michigan.
# Added href /detroit/quests/escape-room-novi-cabin-in-the-woods for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-witching-hour for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-airlock-escape for /detroit in michigan.
# Added href /detroit/quests/escape-room-novi-the-bunker for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-zombie-bomb for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-mystical-forest for /detroit in michigan.
# Added href /detroit/quests/breakout-escape-rooms-elf-myself for /detroit in michigan.
# Added href /detroit/quests/breakout-escape-rooms-chamber-of-illusions for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-dragons-heart for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-kraken-steampunk-casino for /detroit in michigan.
# Added href /detroit/quests/xtreme-escape-rooms-the-haunted-attic for /detroit in michigan.
# Added href /detroit/quests/ideal-escape-rooms-malt-mayhem-shop for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-the-morgue for /detroit in michigan.
# Added href /detroit/quests/think-it-out-campout for /detroit in michigan.
# Added href /detroit/quests/escape-room-studios-vampires-lair for /detroit in michigan.
# Added href /detroit/quests/time-2-xcape-level-up for /detroit in michigan.
# Added href /detroit/quests/excape-games-comic-excape for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-stabbin-cabin for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-down-the-rabbit-hole for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-mummys-revenge for /detroit in michigan.
# Added href /detroit/quests/michigan-escape-room-amnesia for /detroit in michigan.
# Added href /detroit/quests/breakout-escape-rooms-game-of-espionage for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-secret-agent-313 for /detroit in michigan.
# Added href /detroit/quests/the-fifth-wall-escape-rooms-the-purple-gang for /detroit in michigan.
# Added href /detroit/quests/the-great-escape-room-royal-oak-escape-the-colosseum for /detroit in michigan.
# Added href /detroit/quests/xtreme-escape-rooms-mardi-gras for /detroit in michigan.
# Added href /detroit/quests/rush2escape-wimpys-hideaway for /detroit in michigan.
# Added href /detroit/quests/erebus-escape-body-of-evidence for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-captive for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-kentsworth-sanitarium for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-meltdown for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-medusas-revenge for /detroit in michigan.
# Added href /detroit/quests/think-it-out-the-locker-room for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-temple-run for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-hangover for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-escape-from-hogwarts for /detroit in michigan.
# Added href /detroit/quests/ideal-escape-rooms-quest-for-the-throne for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-pirates-of-the-dark-sea for /detroit in michigan.
# Added href /detroit/quests/escape-room-novi-the-circus for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-lost-in-space for /detroit in michigan.
# Added href /detroit/quests/escape-room-zone-draculas-lair for /detroit in michigan.
# Added href /detroit/quests/escape-room-novi-the-rise-of-dracula for /detroit in michigan.
# Added href /detroit/quests/the-great-escape-room-the-gameroom for /detroit in michigan.
# Added href /detroit/quests/the-fifth-wall-escape-rooms-the-harry-houdini-trap for /detroit in michigan.
# Added href /detroit/quests/escape-room-novi-school-of-magic for /detroit in michigan.
# Added href /detroit/quests/trapped-downriver-the-asylum for /detroit in michigan.
# Added href /detroit/quests/descape-mission-mission-curse-of-malachi for /detroit in michigan.
# Added href /detroit/quests/escape-room-novi-jungle-room for /detroit in michigan.
# Added href /detroit/quests/trapped-downriver-area-32 for /detroit in michigan.
# Added href /detroit/quests/alley-escape-telegraph for /detroit in michigan.
# Added href /detroit/quests/escape-room-novi-st-agnes-asylum for /detroit in michigan.
# Added href /flint/quests/spymaker-escape-rooms-the-alchemist for /flint in michigan.
# Added href /flint/quests/great-lakes-escape-game-black-beards-brig for /flint in michigan.
# Added href /flint/quests/great-lakes-escape-game-the-heist for /flint in michigan.
# Added href /flint/quests/spymaker-escape-rooms-escape-the-80s for /flint in michigan.
# Added href /flint/quests/great-lakes-escape-game-lucky-duck-speakeasy for /flint in michigan.
# Added href /flint/quests/spymaker-escape-rooms-spymaker for /flint in michigan.
# Added href /flint/quests/great-lakes-escape-game-immunity-quest for /flint in michigan.
# Added href /flint/quests/spymaker-escape-rooms-dead-mans-hand for /flint in michigan.
# Added href /flint/quests/spymaker-escape-rooms-the-catacombs for /flint in michigan.
# Added href /flint/quests/crack-the-code-escape-the-zombie for /flint in michigan.
# Added href /flint/quests/crack-the-code-voodoo-queen for /flint in michigan.
# Added href /gaylord/quests/escape-the-cabin-jail-escape-game for /gaylord in michigan.
# Added href /grand-haven/quests/grand-haven-room-escape-the-autopsy for /grand-haven in michigan.
# Added href /grand-haven/quests/grand-haven-room-escape-the-attic for /grand-haven in michigan.
# Added href /grand-haven/quests/grand-haven-room-escape-the-bail-shop for /grand-haven in michigan.
# Added href /grand-rapids/quests/locked-460-escape-rooms-apartment-460 for /grand-rapids in michigan.
# Added href /grand-rapids/quests/the-great-escape-room-grand-rapids-moriarty for /grand-rapids in michigan.
# Added href /grand-rapids/quests/the-great-escape-room-the-library-sherlocks-study for /grand-rapids in michigan.
# Added href /grand-rapids/quests/the-great-escape-room-grand-rapids-the-presidents-bunker for /grand-rapids in michigan.
# Added href /grand-rapids/quests/locked-460-escape-rooms-wanted for /grand-rapids in michigan.
# Added href /grand-rapids/quests/the-ruse-escape-rooms-the-inventors-guild for /grand-rapids in michigan.
# Added href /grand-rapids/quests/the-ruse-escape-rooms-the-trophy-room for /grand-rapids in michigan.
# Added href /grand-rapids/quests/grand-rapids-escape-room-the-cure for /grand-rapids in michigan.
# Added href /grand-rapids/quests/grand-rapids-escape-room-licastros-lair for /grand-rapids in michigan.
# Added href /grand-rapids/quests/grand-rapids-escape-room-judgment for /grand-rapids in michigan.
# Added href /grand-rapids/quests/locked-up-grand-rapids-bank-heist for /grand-rapids in michigan.
# Added href /grand-rapids/quests/locked-up-grand-rapids-contaminated for /grand-rapids in michigan.
# Added href /grand-rapids/quests/locked-460-escape-rooms-lous-garage for /grand-rapids in michigan.
# Added href /grand-rapids/quests/escape-20-20-grand-rapids-the-lab for /grand-rapids in michigan.
# Added href /grand-rapids/quests/locked-up-grand-rapids-the-midnight-carnival for /grand-rapids in michigan.
# Added href /grand-rapids/quests/the-great-escape-room-grand-rapids-escape-artist for /grand-rapids in michigan.
# Added href /grand-rapids/quests/escape-20-20-grand-rapids-mafia-escape-room for /grand-rapids in michigan.
# Added href /grand-rapids/quests/locked-up-grand-rapids-attica for /grand-rapids in michigan.
# Added href /grand-rapids/quests/the-great-escape-room-grand-rapids-dr-watsons-infirmary for /grand-rapids in michigan.
# Added href /grand-rapids/quests/grand-rapids-escape-room-hacker for /grand-rapids in michigan.
# Added href /grand-rapids/quests/escape-20-20-grand-rapids-the-parlor for /grand-rapids in michigan.
# Added href /grayling/quests/northern-michigan-escape-rooms-the-black-door for /grayling in michigan.
# Added href /grayling/quests/northern-michigan-escape-rooms-submarine for /grayling in michigan.
# Added href /grayling/quests/northern-michigan-escape-rooms-the-pirate-ship for /grayling in michigan.
# Added href /grayling/quests/northern-michigan-escape-rooms-cdc-lab for /grayling in michigan.
# Added href /hart/quests/bamboozled-escape-rooms-the-dormroom for /hart in michigan.
# Added href /hart/quests/bamboozled-escape-rooms-the-den for /hart in michigan.
# Added href /hart/quests/bamboozled-escape-rooms-the-shop for /hart in michigan.
# Added href /imlay-city/quests/123-escape-rooms-dragons-cave for /imlay-city in michigan.
# Added href /imlay-city/quests/123-escape-rooms-mind-game for /imlay-city in michigan.
# Added href /jackson-mi/quests/epiq-escapes-escape-the-90s for /jackson-mi in michigan.
# Added href /jackson-mi/quests/epiq-escapes-the-back-alley for /jackson-mi in michigan.
# Added href /jackson-mi/quests/epiq-escapes-the-game-show for /jackson-mi in michigan.
# Added href /jackson-mi/quests/epiq-escapes-the-attic for /jackson-mi in michigan.
# Added href /lansing/quests/breakout-escape-rooms-lansing-zombie-roadhouse for /lansing in michigan.
# Added href /lansing/quests/challenges-east-lansing-shipwrecked for /lansing in michigan.
# Added href /lansing/quests/breakout-escape-rooms-lansing-the-ringmasters-den for /lansing in michigan.
# Added href /lansing/quests/breakout-escape-rooms-lansing-game-of-espionage for /lansing in michigan.
# Added href /lansing/quests/challenges-east-lansing-rivalry for /lansing in michigan.
# Added href /lansing/quests/escapology-lansing-budapest-express for /lansing in michigan.
# Added href /lansing/quests/escapology-lansing-under-pressure for /lansing in michigan.
# Added href /lansing/quests/challenges-east-lansing-the-naughty-list for /lansing in michigan.
# Added href /lansing/quests/escapology-lansing-cuban-crisis for /lansing in michigan.
# Added href /lansing/quests/challenges-east-lansing-the-room-of-no-return for /lansing in michigan.
# Added href /lansing/quests/breakout-escape-rooms-lansing-chamber-of-illusions for /lansing in michigan.
# Added href /lansing/quests/escape-20-20-the-alpha-lab for /lansing in michigan.
# Added href /lansing/quests/escape-20-20-the-parlor for /lansing in michigan.
# Added href /lansing/quests/escapology-lansing-antidote for /lansing in michigan.
# Added href /lansing/quests/escape-rooms-portland-mi-dumbledore for /lansing in michigan.
# Added href /lansing/quests/escape-rooms-portland-mi-pharaohs-tomb for /lansing in michigan.
# Added href /lansing/quests/escape-rooms-portland-mi-captured-the-basement for /lansing in michigan.
# Added href /lansing/quests/escape-rooms-portland-mi-gold-mine-last-breath for /lansing in michigan.
# Added href /mackinaw-city/quests/mind-thrill-escape-rooms-pirates-cove for /mackinaw-city in michigan.
# Added href /mackinaw-city/quests/mind-thrill-escape-rooms-fort-escape for /mackinaw-city in michigan.
# Added href /marquette/quests/escape-marquette-the-tomb for /marquette in michigan.
# Added href /marquette/quests/escape-marquette-catch-a-killer for /marquette in michigan.
# Added href /marquette/quests/escape-marquette-detention for /marquette in michigan.
# Added href /marquette/quests/escape-marquette-yooper-camp for /marquette in michigan.
# Added href /midland/quests/cinergys-extreme-escape-room-haunting for /midland in michigan.
# Added href /midland/quests/cinergys-extreme-escape-room-zombie-hour for /midland in michigan.
# Added href /midland/quests/cinergys-extreme-escape-room-diamond-heist for /midland in michigan.
# Added href /midland/quests/mystery-chamber-the-royal-quest for /midland in michigan.
# Added href /midland/quests/mystery-chamber-last-chance for /midland in michigan.
# Added href /midland/quests/mystery-chamber-cash-envy for /midland in michigan.
# Added href /monroe-mi/quests/monroe-escape-rooms-area-51 for /monroe-mi in michigan.
# Added href /monroe-mi/quests/monroe-escape-rooms-merlins-castle for /monroe-mi in michigan.
# Added href /monroe-mi/quests/monroe-escape-rooms-sherlock-holmes for /monroe-mi in michigan.
# Added href /monroe-mi/quests/monroe-escape-rooms-pirate-chest-quest for /monroe-mi in michigan.
# Added href /mt-pleasant/quests/intrigue-escape-games-save-the-concert for /mt-pleasant in michigan.
# Added href /mt-pleasant/quests/intrigue-escape-games-crazy-christmas-heist for /mt-pleasant in michigan.
# Added href /mt-pleasant/quests/central-escapes-christmas-chaos for /mt-pleasant in michigan.
# Added href /mt-pleasant/quests/intrigue-escape-games-dinosaur-detective for /mt-pleasant in michigan.
# Added href /mt-pleasant/quests/central-escapes-area-52 for /mt-pleasant in michigan.
# Added href /muskegon/quests/let-us-go-escape-rooms-secret-agent-man for /muskegon in michigan.
# Added href /muskegon/quests/let-us-go-escape-rooms-the-lost-prophecy for /muskegon in michigan.
# Added href /onsted/quests/old-west-escape-caboose for /onsted in michigan.
# Added href /petoskey/quests/know-way-out-medieval-mayhem for /petoskey in michigan.
# Added href /petoskey/quests/know-way-out-mad-hatters-asylum for /petoskey in michigan.
# Added href /petoskey/quests/know-way-out-savage-safari for /petoskey in michigan.
# Added href /petoskey/quests/know-way-out-the-eyeland for /petoskey in michigan.
# Added href /port-huron/quests/the-hallway-escape-murder-mystery for /port-huron in michigan.
# Added href /port-huron/quests/the-hallway-escape-the-sunken-freighter for /port-huron in michigan.
# Added href /port-huron/quests/the-hallway-escape-the-photographers-darkroom-and-studio for /port-huron in michigan.
# Added href /portage/quests/escapology-portage-antidote for /portage in michigan.
# Added href /portage/quests/clock-n-lock-baby-unicorn-rescue for /portage in michigan.
# Added href /portage/quests/escapology-portage-7-deadly-sins for /portage in michigan.
# Added href /portage/quests/escapology-portage-lost-city for /portage in michigan.
# Added href /portage/quests/clock-n-lock-the-ufo-diner for /portage in michigan.
# Added href /portage/quests/escapology-portage-mansion-murder for /portage in michigan.
# Added href /portage/quests/clock-n-lock-amelias-attic for /portage in michigan.
# Added href /portage/quests/escapology-portage-under-pressure for /portage in michigan.
# Added href /portage/quests/escapology-portage-arizona-shootout for /portage in michigan.
# Added href /portage/quests/the-final-clue-the-playroom for /portage in michigan.
# Added href /portage/quests/the-final-clue-the-firestarter for /portage in michigan.
# Added href /portage/quests/the-final-clue-royal-blood for /portage in michigan.
# Added href /bay-city/quests/xscapequest-da-vincis-room for /bay-city in michigan.
# Added href /bay-city/quests/xscapequest-the-bunker for /bay-city in michigan.
# Added href /bay-city/quests/xscapequest-area-51 for /bay-city in michigan.
# Added href /bay-city/quests/code-breakers-shooters-saloon for /bay-city in michigan.
# Added href /bay-city/quests/saginaw-escape-bad-moon-rising for /bay-city in michigan.
# Added href /bay-city/quests/xscapequest-immersive-x for /bay-city in michigan.
# Added href /bay-city/quests/saginaw-escape-the-n-virus for /bay-city in michigan.
# Added href /bay-city/quests/saginaw-escape-the-killers-promise for /bay-city in michigan.
# Added href /bay-city/quests/code-breakers-el-cazador-shipwreck for /bay-city in michigan.
# Added href /bay-city/quests/paradox-point-benedicts-study for /bay-city in michigan.
# Added href /bay-city/quests/paradox-point-nevermore for /bay-city in michigan.
# Added href /bay-city/quests/paradox-point-the-picture-of-dorian-gray for /bay-city in michigan.
# Added href /st-joseph-mi/quests/puzzlemental-henchmens-hideout for /st-joseph-mi in michigan.
# Added href /st-joseph-mi/quests/puzzlemental-anarchist for /st-joseph-mi in michigan.
# Added href /st-joseph-mi/quests/zoya-escape-rooms-secret-warehouse for /st-joseph-mi in michigan.
# Added href /st-joseph-mi/quests/zoya-escape-rooms-toymaker-workshop for /st-joseph-mi in michigan.
# Added href /st-joseph-mi/quests/puzzlemental-the-source-stone for /st-joseph-mi in michigan.
# Added href /st-joseph-mi/quests/zoya-escape-rooms-alien-escape for /st-joseph-mi in michigan.
# Added href /traverse-city/quests/hectic-escape-challenge-the-miners-cabin for /traverse-city in michigan.
# Added href /traverse-city/quests/hectic-escape-challenge-the-witching-hour for /traverse-city in michigan.
# Added href /traverse-city/quests/escapology-traverse-city-the-code for /traverse-city in michigan.
# Added href /traverse-city/quests/escape-routes-llc-in-zanes-basement for /traverse-city in michigan.
# Added href /traverse-city/quests/escapology-traverse-city-antidote for /traverse-city in michigan.
# Added href /traverse-city/quests/escapology-traverse-city-budapest-express for /traverse-city in michigan.
# Added href /traverse-city/quests/escape-routes-llc-the-cherry-pit for /traverse-city in michigan.
# Added href /zeeland/quests/escape-out-of-the-box-last-will for /zeeland in michigan.
# Added href /zeeland/quests/escape-out-of-the-box-conspiracy for /zeeland in michigan.
# Added href /zeeland/quests/bam-da-vincis-study for /zeeland in michigan.
# Added href /zeeland/quests/bam-draculas-crypt for /zeeland in michigan.
# Added href /zeeland/quests/bam-zombie-lab for /zeeland in michigan.
# Added href /zeeland/quests/bam-houdinis-seance for /zeeland in michigan.

# %%
state_city_room_urls
# Out:
# {'alabama': {'/auburn': ['/auburn/quests/auburn-escape-zones-the-cabin',
#    '/auburn/quests/auburn-escape-zones-imprisoned',
#    '/auburn/quests/auburn-escape-zones-the-puzzler-vs-superheroes',
#    '/auburn/quests/auburn-escape-zones-vault',
#    '/auburn/quests/auburn-escape-zones-black-beards-brig'],
#   '/birm': ['/birm/quests/Locked-In-THE-LABORATORY',
#    '/birm/quests/locked-in-birm-the-classroom',
#    '/birm/quests/Locked-In-THE-WAREHOUSE',
#    '/birm/quests/nightmare-at-3008-3008-house',
#    '/birm/quests/nightmare-at-3008-camp-mary-lee',
#    '/birm/quests/nightmare-at-3008-the-underground',
#    '/birm/quests/train-escape-sabotage',
#    '/birm/quests/train-escape-classified',
#    '/birm/quests/Locked-In-THE-MUSEUM'],
#   '/daleville': ['/daleville/quests/brain-busters-escape-rooms-the-grove',
#    '/daleville/quests/brain-busters-escape-rooms-booty-battle',
#    '/daleville/quests/brain-busters-escape-rooms-out-of-order',
#    '/daleville/quests/brain-busters-escape-rooms-wizard-quest',
#    '/daleville/quests/brain-busters-escape-rooms-bio-lab',
#    '/daleville/quests/escape-enterprise-the-box',
#    '/daleville/quests/escape-enterprise-the-secret-society',
#    '/daleville/quests/escape-enterprise-the-shack'],
#   '/dothan': ['/dothan/quests/escape-dothan-the-13th-floor',
#    '/dothan/quests/escape-dothan-murder-at-the-mansion',
#    '/dothan/quests/escape-dothan-time-warp',
#    '/dothan/quests/escape-dothan-bazaar-battle'],
#   '/florence-al': ['/florence-al/quests/escape-room-florence-lost-cabin',
#    '/florence-al/quests/escape-room-florence-espionage',
#    '/florence-al/quests/escape-room-florence-sound-escape',
#    '/florence-al/quests/escape-room-florence-bio-hazard-bunker'],
#   '/gadsden': ['/gadsden/quests/beat60-the-darkness',
#    '/gadsden/quests/beat60-the-captain',
#    '/gadsden/quests/beat60-jewel-thief'],
#   '/henagar': ['/henagar/quests/escape-room-adventures-zombie-escape',
#    '/henagar/quests/escape-room-adventures-dash-for-the-cash'],
#   '/huntsville': ['/huntsville/quests/huntsville-escape-rooms-the-hexadron',
#    '/huntsville/quests/Huntsville-Escape-Rooms-The-Psyche-Ward',
#    '/huntsville/quests/Huntsville-Escape-Rooms-The-Informant',
#    '/huntsville/quests/huntsville-escape-rooms-the-queen-pin',
#    '/huntsville/quests/huntsville-escape-rooms-the-new-atlantis',
#    '/huntsville/quests/escapology-huntsville-budapest-express',
#    '/huntsville/quests/huntsville-escape-rooms-the-executioner',
#    '/huntsville/quests/escapology-huntsville-antidote',
#    '/huntsville/quests/escapology-huntsville-under-pressure',
#    '/huntsville/quests/trapped-in-decatur-escape-from-alcatraz',
#    '/huntsville/quests/trapped-in-decatur-the-bank-robbery',
#    '/huntsville/quests/trapped-in-decatur-treasure-of-the-emerald-isles',
#    '/huntsville/quests/trapped-in-decatur-the-morgue-of-dr-g-reaper'],
#   '/mobile': ['/mobile/quests/fairhope-escape-rooms-night-bandit-treasure'],
#   '/montgomery': ['/montgomery/quests/escapology-montgomery-antidote',
#    '/montgomery/quests/escapology-montgomery-cuban-crisis',
#    '/montgomery/quests/escapology-montgomery-budapest-express',
#    '/montgomery/quests/escapology-montgomery-arizona-shootout',
#    '/montgomery/quests/escapology-montgomery-shanghaied',
#    '/montgomery/quests/escapology-montgomery-the-code',
#    '/montgomery/quests/breakout-montgomery-hostage',
#    '/montgomery/quests/breakout-montgomery-the-kidnapping',
#    '/montgomery/quests/breakout-montgomery-museum-heist',
#    '/montgomery/quests/breakout-games-montgomery-mystery-mansion',
#    '/montgomery/quests/breakout-montgomery-operation-casino'],
#   '/gulf-shores': ['/gulf-shores/quests/get-a-clue-crime-scene',
#    '/gulf-shores/quests/Gulf-Coast-Escape-Room-THE-DOLL-ROOM',
#    '/gulf-shores/quests/get-a-clue-mardi-gras',
#    '/gulf-shores/quests/escape-house-waterville-the-room-of-the-great-mysto',
#    '/gulf-shores/quests/xit-escape-room-insane-asylum',
#    '/gulf-shores/quests/Gulf-Coast-Escape-Room-ZOMBIE-LAB',
#    '/gulf-shores/quests/xit-escape-room-csi-gulf-shores',
#    '/gulf-shores/quests/gulf-coast-escape-room-bates-motel',
#    '/gulf-shores/quests/get-a-clue-paranormal-investigation',
#    '/gulf-shores/quests/xit-escape-room-a-tale-of-two-forts',
#    '/gulf-shores/quests/xit-escape-room-movie-night',
#    '/gulf-shores/quests/escape-house-waterville-the-hurricane-room',
#    '/gulf-shores/quests/gulf-coast-escape-room-gs-voodoo-cabin'],
#   '/oxford-al': ['/oxford-al/quests/escape-zone-oxford-the-golden-formula',
#    '/oxford-al/quests/escape-zone-oxford-the-bank-heist',
#    '/oxford-al/quests/escape-zone-oxford-sulleys-sinking-ship'],
#   '/tuscaloosa': ['/tuscaloosa/quests/Horror-Hotel',
#    '/tuscaloosa/quests/escape-tuscaloosa-the-cabin',
#    '/tuscaloosa/quests/escape-tuscaloosa-the-prison',
#    '/tuscaloosa/quests/escape-tuscaloosa-the-playbook',
#    '/tuscaloosa/quests/breakout-tuscaloosa-derailed',
#    '/tuscaloosa/quests/breakout-tuscaloosa-the-mission',
#    '/tuscaloosa/quests/escape-tuscaloosa-the-haunted',
#    '/tuscaloosa/quests/escape-tuscaloosa-abducted',
#    '/tuscaloosa/quests/all-in-adventures-escape-from-alcatraz',
#    '/tuscaloosa/quests/all-in-adventures-treasure-island',
#    '/tuscaloosa/quests/all-in-adventures-sherlocks-library']},
#  'michigan': {'/ann-arbor': ['/ann-arbor/quests/decode-detroit-the-minerva-project',
#    '/ann-arbor/quests/breakout-escape-rooms-ann-arbor-zombie-roadhouse',
#    '/ann-arbor/quests/clueless-escape-rooms-save-tony',
#    '/ann-arbor/quests/breakout-escape-rooms-ann-arbor-game-of-espionage',
#    '/ann-arbor/quests/decode-detroit-minervas-return',
#    '/ann-arbor/quests/breakout-escape-rooms-ann-arbor-the-ringmasters-den',
#    '/ann-arbor/quests/breakout-escape-rooms-ann-arbor-chamber-of-illusions',
#    '/ann-arbor/quests/clueless-escape-rooms-candy-caper',
#    '/ann-arbor/quests/decode-escape-room-the-minerva-project',
#    '/ann-arbor/quests/clueless-escape-rooms-castaway-island',
#    '/ann-arbor/quests/clueless--escape-rooms-corporate-escape',
#    '/ann-arbor/quests/clueless-escape-rooms-football-fury'],
#   '/battle-creek': ['/battle-creek/quests/break-escape-the-cabin',
#    '/battle-creek/quests/break-escape-the-library'],
#   '/brighton-mi': ['/brighton-mi/quests/puzzled-escape-surviving-the-apocalypse',
#    '/brighton-mi/quests/puzzled-escape-the-laboratory',
#    '/brighton-mi/quests/puzzled-escape-patient-37'],
#   '/clinton': [],
#   '/davison': ['/davison/quests/michigan-escape-games-mission-impossibly',
#    '/davison/quests/michigan-escape-games-csl-homicide-detectives',
#    '/davison/quests/michigan-escape-games-viral-containment-cdc-labs',
#    '/davison/quests/michigan-escape-games-the-heist',
#    '/davison/quests/Michiga-Escape-Games-CheckMate',
#    '/davison/quests/michigan-escape-games-the-dwelling',
#    '/davison/quests/michigan-escape-games-the-steampunk-time-machine',
#    '/davison/quests/michigan-escape-games-blackout',
#    '/davison/quests/michigan-escape-games-meltdown',
#    '/davison/quests/michigan-escape-games-final-breath'],
#   '/detroit': ['/detroit/quests/erebus-escape-lockdown',
#    '/detroit/quests/xtreme-escape-rooms-patient-zero',
#    '/detroit/quests/escape-the-post-zombie-apocalypse',
#    '/detroit/quests/michigan-escape-room-the-elevator',
#    '/detroit/quests/descape-mission-mission-motown',
#    '/detroit/quests/Breakout-The-Room-Escape-Game-Zombie-Roadhouse-W',
#    '/detroit/quests/xtreme-escape-rooms-time-bomb',
#    '/detroit/quests/escape-the-room-detroit-the-dig',
#    '/detroit/quests/ideal-escape-rooms-escape-the-wild-west',
#    '/detroit/quests/escape-room-novi-the-illusionist',
#    '/detroit/quests/excape-games-murder-mystery',
#    '/detroit/quests/Breakout-The-Room-Escape-Game-The-Ringmasters-Den-W',
#    '/detroit/quests/escape-the-post-the-cell',
#    '/detroit/quests/escape-room-novi-tonys-bistro',
#    '/detroit/quests/escape-room-novi-pirates-of-the-seas',
#    '/detroit/quests/rush2escape-bank-heist-gone-wrong',
#    '/detroit/quests/the-great-escape-room-the-library-sherlocks-study',
#    '/detroit/quests/escape-the-post-the-bistro',
#    '/detroit/quests/excape-games-jail-break',
#    '/detroit/quests/escape-room-zone-bank-heist',
#    '/detroit/quests/escape-room-zone-mad-scientist',
#    '/detroit/quests/michigan-escape-room-kidnapped-in-the-warehouse',
#    '/detroit/quests/excape-games-abandon-ship',
#    '/detroit/quests/michigan-escape-room-saloon',
#    '/detroit/quests/ecsape-room-zone-prison-break',
#    '/detroit/quests/michigan-escape-room-misfortune',
#    '/detroit/quests/escape-room-studios-steampunk-gypsies',
#    '/detroit/quests/the-great-escape-room-the-infirmary',
#    '/detroit/quests/the-great-escape-room-royal-oak-the-presidents-bunker',
#    '/detroit/quests/escape-room-zone-pharaohs-curse',
#    '/detroit/quests/time-2-xcape-crack-the-case',
#    '/detroit/quests/escape-the-post-find-teddy',
#    '/detroit/quests/escape-room-zone-pirates-curse',
#    '/detroit/quests/escape-the-post-the-sheriffs-office',
#    '/detroit/quests/think-it-out-superhero-university',
#    '/detroit/quests/clever-clues-escape-room-the-precinct',
#    '/detroit/quests/clever-clues-escape-room-the-meltdown',
#    '/detroit/quests/escape-the-room-detroit-the-rec-room',
#    '/detroit/quests/escape-room-novi-the-speakeasy',
#    '/detroit/quests/escape-the-room-detroit-agency',
#    '/detroit/quests/ideal-escape-rooms-firefighter-rescue',
#    '/detroit/quests/time-2-xcape-crash-landing',
#    '/detroit/quests/escape-room-novi-cabin-in-the-woods',
#    '/detroit/quests/escape-room-zone-witching-hour',
#    '/detroit/quests/escape-room-zone-airlock-escape',
#    '/detroit/quests/escape-room-novi-the-bunker',
#    '/detroit/quests/escape-room-zone-zombie-bomb',
#    '/detroit/quests/escape-room-zone-mystical-forest',
#    '/detroit/quests/breakout-escape-rooms-elf-myself',
#    '/detroit/quests/breakout-escape-rooms-chamber-of-illusions',
#    '/detroit/quests/escape-room-zone-dragons-heart',
#    '/detroit/quests/escape-room-zone-kraken-steampunk-casino',
#    '/detroit/quests/xtreme-escape-rooms-the-haunted-attic',
#    '/detroit/quests/ideal-escape-rooms-malt-mayhem-shop',
#    '/detroit/quests/escape-room-zone-the-morgue',
#    '/detroit/quests/think-it-out-campout',
#    '/detroit/quests/escape-room-studios-vampires-lair',
#    '/detroit/quests/time-2-xcape-level-up',
#    '/detroit/quests/excape-games-comic-excape',
#    '/detroit/quests/escape-room-zone-stabbin-cabin',
#    '/detroit/quests/escape-room-zone-down-the-rabbit-hole',
#    '/detroit/quests/escape-room-zone-mummys-revenge',
#    '/detroit/quests/michigan-escape-room-amnesia',
#    '/detroit/quests/breakout-escape-rooms-game-of-espionage',
#    '/detroit/quests/escape-room-zone-secret-agent-313',
#    '/detroit/quests/the-fifth-wall-escape-rooms-the-purple-gang',
#    '/detroit/quests/the-great-escape-room-royal-oak-escape-the-colosseum',
#    '/detroit/quests/xtreme-escape-rooms-mardi-gras',
#    '/detroit/quests/rush2escape-wimpys-hideaway',
#    '/detroit/quests/erebus-escape-body-of-evidence',
#    '/detroit/quests/escape-room-zone-captive',
#    '/detroit/quests/escape-room-zone-kentsworth-sanitarium',
#    '/detroit/quests/escape-room-zone-meltdown',
#    '/detroit/quests/escape-room-zone-medusas-revenge',
#    '/detroit/quests/think-it-out-the-locker-room',
#    '/detroit/quests/escape-room-zone-temple-run',
#    '/detroit/quests/escape-room-zone-hangover',
#    '/detroit/quests/escape-room-zone-escape-from-hogwarts',
#    '/detroit/quests/ideal-escape-rooms-quest-for-the-throne',
#    '/detroit/quests/escape-room-zone-pirates-of-the-dark-sea',
#    '/detroit/quests/escape-room-novi-the-circus',
#    '/detroit/quests/escape-room-zone-lost-in-space',
#    '/detroit/quests/escape-room-zone-draculas-lair',
#    '/detroit/quests/escape-room-novi-the-rise-of-dracula',
#    '/detroit/quests/the-great-escape-room-the-gameroom',
#    '/detroit/quests/the-fifth-wall-escape-rooms-the-harry-houdini-trap',
#    '/detroit/quests/escape-room-novi-school-of-magic',
#    '/detroit/quests/trapped-downriver-the-asylum',
#    '/detroit/quests/descape-mission-mission-curse-of-malachi',
#    '/detroit/quests/escape-room-novi-jungle-room',
#    '/detroit/quests/trapped-downriver-area-32',
#    '/detroit/quests/alley-escape-telegraph',
#    '/detroit/quests/escape-room-novi-st-agnes-asylum'],
#   '/flint': ['/flint/quests/spymaker-escape-rooms-the-alchemist',
#    '/flint/quests/great-lakes-escape-game-black-beards-brig',
#    '/flint/quests/great-lakes-escape-game-the-heist',
#    '/flint/quests/spymaker-escape-rooms-escape-the-80s',
#    '/flint/quests/great-lakes-escape-game-lucky-duck-speakeasy',
#    '/flint/quests/spymaker-escape-rooms-spymaker',
#    '/flint/quests/great-lakes-escape-game-immunity-quest',
#    '/flint/quests/spymaker-escape-rooms-dead-mans-hand',
#    '/flint/quests/spymaker-escape-rooms-the-catacombs',
#    '/flint/quests/crack-the-code-escape-the-zombie',
#    '/flint/quests/crack-the-code-voodoo-queen'],
#   '/gaylord': ['/gaylord/quests/escape-the-cabin-jail-escape-game'],
#   '/grand-haven': ['/grand-haven/quests/grand-haven-room-escape-the-autopsy',
#    '/grand-haven/quests/grand-haven-room-escape-the-attic',
#    '/grand-haven/quests/grand-haven-room-escape-the-bail-shop'],
#   '/grand-rapids': ['/grand-rapids/quests/locked-460-escape-rooms-apartment-460',
#    '/grand-rapids/quests/the-great-escape-room-grand-rapids-moriarty',
#    '/grand-rapids/quests/the-great-escape-room-the-library-sherlocks-study',
#    '/grand-rapids/quests/the-great-escape-room-grand-rapids-the-presidents-bunker',
#    '/grand-rapids/quests/locked-460-escape-rooms-wanted',
#    '/grand-rapids/quests/the-ruse-escape-rooms-the-inventors-guild',
#    '/grand-rapids/quests/the-ruse-escape-rooms-the-trophy-room',
#    '/grand-rapids/quests/grand-rapids-escape-room-the-cure',
#    '/grand-rapids/quests/grand-rapids-escape-room-licastros-lair',
#    '/grand-rapids/quests/grand-rapids-escape-room-judgment',
#    '/grand-rapids/quests/locked-up-grand-rapids-bank-heist',
#    '/grand-rapids/quests/locked-up-grand-rapids-contaminated',
#    '/grand-rapids/quests/locked-460-escape-rooms-lous-garage',
#    '/grand-rapids/quests/escape-20-20-grand-rapids-the-lab',
#    '/grand-rapids/quests/locked-up-grand-rapids-the-midnight-carnival',
#    '/grand-rapids/quests/the-great-escape-room-grand-rapids-escape-artist',
#    '/grand-rapids/quests/escape-20-20-grand-rapids-mafia-escape-room',
#    '/grand-rapids/quests/locked-up-grand-rapids-attica',
#    '/grand-rapids/quests/the-great-escape-room-grand-rapids-dr-watsons-infirmary',
#    '/grand-rapids/quests/grand-rapids-escape-room-hacker',
#    '/grand-rapids/quests/escape-20-20-grand-rapids-the-parlor'],
#   '/grayling': ['/grayling/quests/northern-michigan-escape-rooms-the-black-door',
#    '/grayling/quests/northern-michigan-escape-rooms-submarine',
#    '/grayling/quests/northern-michigan-escape-rooms-the-pirate-ship',
#    '/grayling/quests/northern-michigan-escape-rooms-cdc-lab'],
#   '/hart': ['/hart/quests/bamboozled-escape-rooms-the-dormroom',
#    '/hart/quests/bamboozled-escape-rooms-the-den',
#    '/hart/quests/bamboozled-escape-rooms-the-shop'],
#   '/imlay-city': ['/imlay-city/quests/123-escape-rooms-dragons-cave',
#    '/imlay-city/quests/123-escape-rooms-mind-game'],
#   '/jackson-mi': ['/jackson-mi/quests/epiq-escapes-escape-the-90s',
#    '/jackson-mi/quests/epiq-escapes-the-back-alley',
#    '/jackson-mi/quests/epiq-escapes-the-game-show',
#    '/jackson-mi/quests/epiq-escapes-the-attic'],
#   '/lansing': ['/lansing/quests/breakout-escape-rooms-lansing-zombie-roadhouse',
#    '/lansing/quests/challenges-east-lansing-shipwrecked',
#    '/lansing/quests/breakout-escape-rooms-lansing-the-ringmasters-den',
#    '/lansing/quests/breakout-escape-rooms-lansing-game-of-espionage',
#    '/lansing/quests/challenges-east-lansing-rivalry',
#    '/lansing/quests/escapology-lansing-budapest-express',
#    '/lansing/quests/escapology-lansing-under-pressure',
#    '/lansing/quests/challenges-east-lansing-the-naughty-list',
#    '/lansing/quests/escapology-lansing-cuban-crisis',
#    '/lansing/quests/challenges-east-lansing-the-room-of-no-return',
#    '/lansing/quests/breakout-escape-rooms-lansing-chamber-of-illusions',
#    '/lansing/quests/escape-20-20-the-alpha-lab',
#    '/lansing/quests/escape-20-20-the-parlor',
#    '/lansing/quests/escapology-lansing-antidote',
#    '/lansing/quests/escape-rooms-portland-mi-dumbledore',
#    '/lansing/quests/escape-rooms-portland-mi-pharaohs-tomb',
#    '/lansing/quests/escape-rooms-portland-mi-captured-the-basement',
#    '/lansing/quests/escape-rooms-portland-mi-gold-mine-last-breath'],
#   '/mackinaw-city': ['/mackinaw-city/quests/mind-thrill-escape-rooms-pirates-cove',
#    '/mackinaw-city/quests/mind-thrill-escape-rooms-fort-escape'],
#   '/marquette': ['/marquette/quests/escape-marquette-the-tomb',
#    '/marquette/quests/escape-marquette-catch-a-killer',
#    '/marquette/quests/escape-marquette-detention',
#    '/marquette/quests/escape-marquette-yooper-camp'],
#   '/midland': ['/midland/quests/cinergys-extreme-escape-room-haunting',
#    '/midland/quests/cinergys-extreme-escape-room-zombie-hour',
#    '/midland/quests/cinergys-extreme-escape-room-diamond-heist',
#    '/midland/quests/mystery-chamber-the-royal-quest',
#    '/midland/quests/mystery-chamber-last-chance',
#    '/midland/quests/mystery-chamber-cash-envy'],
#   '/monroe-mi': ['/monroe-mi/quests/monroe-escape-rooms-area-51',
#    '/monroe-mi/quests/monroe-escape-rooms-merlins-castle',
#    '/monroe-mi/quests/monroe-escape-rooms-sherlock-holmes',
#    '/monroe-mi/quests/monroe-escape-rooms-pirate-chest-quest'],
#   '/mt-pleasant': ['/mt-pleasant/quests/intrigue-escape-games-save-the-concert',
#    '/mt-pleasant/quests/intrigue-escape-games-crazy-christmas-heist',
#    '/mt-pleasant/quests/central-escapes-christmas-chaos',
#    '/mt-pleasant/quests/intrigue-escape-games-dinosaur-detective',
#    '/mt-pleasant/quests/central-escapes-area-52'],
#   '/muskegon': ['/muskegon/quests/let-us-go-escape-rooms-secret-agent-man',
#    '/muskegon/quests/let-us-go-escape-rooms-the-lost-prophecy'],
#   '/onsted': ['/onsted/quests/old-west-escape-caboose'],
#   '/petoskey': ['/petoskey/quests/know-way-out-medieval-mayhem',
#    '/petoskey/quests/know-way-out-mad-hatters-asylum',
#    '/petoskey/quests/know-way-out-savage-safari',
#    '/petoskey/quests/know-way-out-the-eyeland'],
#   '/port-huron': ['/port-huron/quests/the-hallway-escape-murder-mystery',
#    '/port-huron/quests/the-hallway-escape-the-sunken-freighter',
#    '/port-huron/quests/the-hallway-escape-the-photographers-darkroom-and-studio'],
#   '/portage': ['/portage/quests/escapology-portage-antidote',
#    '/portage/quests/clock-n-lock-baby-unicorn-rescue',
#    '/portage/quests/escapology-portage-7-deadly-sins',
#    '/portage/quests/escapology-portage-lost-city',
#    '/portage/quests/clock-n-lock-the-ufo-diner',
#    '/portage/quests/escapology-portage-mansion-murder',
#    '/portage/quests/clock-n-lock-amelias-attic',
#    '/portage/quests/escapology-portage-under-pressure',
#    '/portage/quests/escapology-portage-arizona-shootout',
#    '/portage/quests/the-final-clue-the-playroom',
#    '/portage/quests/the-final-clue-the-firestarter',
#    '/portage/quests/the-final-clue-royal-blood'],
#   '/bay-city': ['/bay-city/quests/xscapequest-da-vincis-room',
#    '/bay-city/quests/xscapequest-the-bunker',
#    '/bay-city/quests/xscapequest-area-51',
#    '/bay-city/quests/code-breakers-shooters-saloon',
#    '/bay-city/quests/saginaw-escape-bad-moon-rising',
#    '/bay-city/quests/xscapequest-immersive-x',
#    '/bay-city/quests/saginaw-escape-the-n-virus',
#    '/bay-city/quests/saginaw-escape-the-killers-promise',
#    '/bay-city/quests/code-breakers-el-cazador-shipwreck',
#    '/bay-city/quests/paradox-point-benedicts-study',
#    '/bay-city/quests/paradox-point-nevermore',
#    '/bay-city/quests/paradox-point-the-picture-of-dorian-gray'],
#   '/st-joseph-mi': ['/st-joseph-mi/quests/puzzlemental-henchmens-hideout',
#    '/st-joseph-mi/quests/puzzlemental-anarchist',
#    '/st-joseph-mi/quests/zoya-escape-rooms-secret-warehouse',
#    '/st-joseph-mi/quests/zoya-escape-rooms-toymaker-workshop',
#    '/st-joseph-mi/quests/puzzlemental-the-source-stone',
#    '/st-joseph-mi/quests/zoya-escape-rooms-alien-escape'],
#   '/traverse-city': ['/traverse-city/quests/hectic-escape-challenge-the-miners-cabin',
#    '/traverse-city/quests/hectic-escape-challenge-the-witching-hour',
#    '/traverse-city/quests/escapology-traverse-city-the-code',
#    '/traverse-city/quests/escape-routes-llc-in-zanes-basement',
#    '/traverse-city/quests/escapology-traverse-city-antidote',
#    '/traverse-city/quests/escapology-traverse-city-budapest-express',
#    '/traverse-city/quests/escape-routes-llc-the-cherry-pit'],
#   '/zeeland': ['/zeeland/quests/escape-out-of-the-box-last-will',
#    '/zeeland/quests/escape-out-of-the-box-conspiracy',
#    '/zeeland/quests/bam-da-vincis-study',
#    '/zeeland/quests/bam-draculas-crypt',
#    '/zeeland/quests/bam-zombie-lab',
#    '/zeeland/quests/bam-houdinis-seance']}}
