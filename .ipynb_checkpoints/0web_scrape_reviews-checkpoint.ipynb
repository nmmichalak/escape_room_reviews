# %% [markdown]
# # Import libraries

# %%
# uncomment to install libraries
# ! pip install numpy pandas matplotlib seaborn requests selenium bs4
# ! pip install jupyter_contrib_nbextensions && jupyter contrib nbextension install 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import selenium
from bs4 import BeautifulSoup
import time

# %% [markdown]
# # Test web scraping escape room reviews

# %% [markdown]
# ## World of Escapes map page URL

# %%
map_page_url = "https://worldofescapes.com/map"

# %% [markdown]
# ## Map page response

# %%
map_page_response = requests.get(map_page_url)

# %% [markdown]
# ## Map page soup

# %%
map_page_soup = BeautifulSoup(map_page_response.text, "html.parser")

# %% [markdown]
# ## Map states and city href

# %%
# dictionary container for states and their city href
states = {}

# loop through states and add their city href
for state_item_i in map_page_soup.find_all("div", {"class": "col-lg-3 col-md-4 col-sm-6 col-xs-6 state-item"}):
    # state str
    state_i = state_item_i.find("h3").get_text().strip().lower()
    
    # add states to dictionary
    states[state_i] = []
    
    # add cities to state values
    for city_item_j in state_item_i.find_all("li", {"class": "city-item"}):
        states[state_i].append(city_item_j.a["href"])

# See it
states
# Out:
# {'alabama': ['/auburn',
#   '/birm',
#   '/daleville',
#   '/dothan',
#   '/florence-al',
#   '/gadsden',
#   '/henagar',
#   '/huntsville',
#   '/mobile',
#   '/montgomery',
#   '/gulf-shores',
#   '/oxford-al',
#   '/tuscaloosa'],
#  'alaska': ['/anchorage', '/fairbanks', '/juneau', '/skagway'],
#  'arizona': ['/cottonwood',
#   '/flagstaff',
#   '/lake-havasu-city',
#   '/phoenix',
#   '/prescott',
#   '/tucson',
#   '/yuma'],
#  'arkansas': ['/bentonville',
#   '/springdale',
#   '/eureka-springs',
#   '/fayetteville-ar',
#   '/fort-smith',
#   '/hot-springs',
#   '/jonesboro',
#   '/little-rock',
#   '/pine-bluff',
#   '/russellville',
#   '/searcy'],
#  'california': ['/bakersfield',
#   '/big-bear-city',
#   '/carlsbad',
#   '/chico',
#   '/eureka',
#   '/fresno',
#   '/grover-beach',
#   '/hesperia',
#   '/lancaster-ca',
#   '/livermore',
#   '/los-angeles',
#   '/modesto',
#   '/oceanside',
#   '/orange-county',
#   '/palm-springs',
#   '/pomona',
#   '/rancho-mirage',
#   '/redding',
#   '/redlands',
#   '/riverside',
#   '/rohnert-park',
#   '/sacramento',
#   '/salinas',
#   '/san-diego',
#   '/sfbay',
#   '/san-jose',
#   '/san-marcos-ca',
#   '/santa-barbara',
#   '/sebastopol',
#   '/south-lake-tahoe',
#   '/temecula',
#   '/ventura',
#   '/windsor-ca',
#   '/yuba-city'],
#  'colorado': ['/avon',
#   '/breckenridge',
#   '/colorado-springs',
#   '/denver',
#   '/durango',
#   '/fort-collins',
#   '/glenwood-springs',
#   '/grand-junction',
#   '/longmont',
#   '/pagosa-springs',
#   '/steamboat-springs'],
#  'connecticut': ['/danbury',
#   '/west-hartford',
#   '/new-haven',
#   '/newington',
#   '/norwich',
#   '/putnam',
#   '/southington',
#   '/stamford',
#   '/stonington'],
#  'delaware': ['/dover', '/newark-de', '/rehoboth-beach', '/wilmington-de'],
#  'florida': ['/crystal-river',
#   '/daytona-beach',
#   '/destin',
#   '/fort-myers',
#   '/gainesville',
#   '/jacksonville',
#   '/key-largo',
#   '/key-west',
#   '/lakeland',
#   '/marco-island',
#   '/melbourne',
#   '/miami',
#   '/okeechobee',
#   '/orlando',
#   '/panama-city',
#   '/pensacola',
#   '/port-st-lucie',
#   '/sarasota',
#   '/st-augustine',
#   '/tallahassee',
#   '/tampa',
#   '/west-palm-beach'],
#  'georgia': ['/albany-ga',
#   '/athens',
#   '/atlanta',
#   '/augusta',
#   '/carrollton',
#   '/columbus-ga',
#   '/cumming',
#   '/dalton',
#   '/macon',
#   '/savannah',
#   '/valdosta'],
#  'hawaii': ['/hawaii',
#   '/honolulu',
#   '/kailua-kona',
#   '/kaneohe',
#   '/kauai',
#   '/lahaina'],
#  'idaho': ['/boise',
#   '/coeur-d-alene',
#   '/idaho-falls',
#   '/lewiston',
#   '/moscow',
#   '/pocatello',
#   '/post-falls',
#   '/rexburg',
#   '/twin-falls'],
#  'illinois': ['/bloomington',
#   '/bradley',
#   '/carbondale',
#   '/champaign',
#   '/chicago',
#   '/effingham',
#   '/elburn',
#   '/frankfort',
#   '/glen-carbon',
#   '/herrin',
#   '/naperville',
#   '/peoria',
#   '/quincy',
#   '/rockford',
#   '/springfield',
#   '/taylorville',
#   '/urbana',
#   '/woodstock'],
#  'indiana': ['/bloomington-in',
#   '/cedar-lake',
#   '/evansville',
#   '/fort-wayne',
#   '/french-lick',
#   '/indianapolis',
#   '/jeffersonville',
#   '/lafayette-in',
#   '/michigan-city',
#   '/muncie',
#   '/schererville',
#   '/south-bend',
#   '/terre-haute',
#   '/valparaiso',
#   '/vincennes',
#   '/wabash'],
#  'iowa': ['/bettendorf',
#   '/cedar-falls',
#   '/cedar-rapids',
#   '/clear-lake',
#   '/coralville',
#   '/dewitt',
#   '/des-moines',
#   '/dubuque',
#   '/okoboji',
#   '/sioux-city'],
#  'kansas': ['/bonner-springs',
#   '/garden-city',
#   '/hays',
#   '/hutchinson',
#   '/lawrence',
#   '/leavenworth',
#   '/manhattan',
#   '/overland-park',
#   '/salina',
#   '/topeka',
#   '/wichita'],
#  'kentucky': ['/bowling-green',
#   '/florence-ky',
#   '/glasgow-ky',
#   '/lexington',
#   '/london',
#   '/louisville',
#   '/owensboro',
#   '/paducah',
#   '/pikeville',
#   '/somerset'],
#  'louisiana': ['/alexandria',
#   '/baton-rouge',
#   '/covington',
#   '/houma',
#   '/lafayette',
#   '/lake-charles',
#   '/monroe',
#   '/natchitoches',
#   '/new-orleans',
#   '/ruston',
#   '/shreveport',
#   '/tickfaw'],
#  'maine': ['/bangor',
#   '/brunswick',
#   '/ellsworth',
#   '/south-portland',
#   '/waterville'],
#  'maryland': ['/annapolis',
#   '/baltimore',
#   '/bel-air',
#   '/california',
#   '/cumberland',
#   '/frederick',
#   '/gambrills',
#   '/grasonville',
#   '/ocean-city',
#   '/rockville',
#   '/salisbury'],
#  'massachusetts': ['/boston',
#   '/easthampton',
#   '/kingston',
#   '/mashpee',
#   '/millbury',
#   '/new-bedford',
#   '/pittsfield',
#   '/taunton',
#   '/webster',
#   '/winchendon',
#   '/worcester'],
#  'michigan': ['/ann-arbor',
#   '/battle-creek',
#   '/brighton-mi',
#   '/clinton',
#   '/davison',
#   '/detroit',
#   '/flint',
#   '/gaylord',
#   '/grand-haven',
#   '/grand-rapids',
#   '/grayling',
#   '/hart',
#   '/imlay-city',
#   '/jackson-mi',
#   '/lansing',
#   '/mackinaw-city',
#   '/marquette',
#   '/midland',
#   '/monroe-mi',
#   '/mt-pleasant',
#   '/muskegon',
#   '/onsted',
#   '/petoskey',
#   '/port-huron',
#   '/portage',
#   '/bay-city',
#   '/st-joseph-mi',
#   '/traverse-city',
#   '/zeeland'],
#  'minnesota': ['/alexandria-mn',
#   '/bemidji',
#   '/brainerd',
#   '/duluth',
#   '/mankato',
#   '/minneapolis',
#   '/park-rapids',
#   '/rochester-mn',
#   '/roseau',
#   '/st-cloud',
#   '/winona'],
#  'mississippi': ['/biloxi',
#   '/corinth',
#   '/hattiesburg',
#   '/jackson-ms',
#   '/oxford-ms',
#   '/picayune',
#   '/starkville',
#   '/tupelo'],
#  'missouri': ['/branson',
#   '/cape-girardeau',
#   '/columbia-mo',
#   '/hannibal',
#   '/jefferson-city',
#   '/joplin',
#   '/kansas-city',
#   '/kirksville',
#   '/lake-ozark',
#   '/maryville',
#   '/springfield-mo',
#   '/st-joseph-mo',
#   '/st-louis',
#   '/west-plains',
#   '/windsor'],
#  'montana': ['/belgrade',
#   '/billings',
#   '/bozeman',
#   '/butte',
#   '/great-falls',
#   '/helena',
#   '/missoula',
#   '/whitefish'],
#  'nebraska': ['/aurora',
#   '/columbus-ne',
#   '/hastings',
#   '/kearney',
#   '/lincoln',
#   '/omaha'],
#  'nevada': ['/las-vegas', '/reno'],
#  'new hampshire': ['/amherst',
#   '/claremont',
#   '/concord',
#   '/derry',
#   '/laconia',
#   '/littleton',
#   '/manchester',
#   '/nashua',
#   '/newbury',
#   '/north-conway',
#   '/portsmouth'],
#  'new jersey': ['/andover',
#   '/atlantic-city',
#   '/bridgewater',
#   '/rio-grande',
#   '/collingswood',
#   '/flemington',
#   '/freehold',
#   '/garwood',
#   '/glassboro',
#   '/long-branch',
#   '/millville',
#   '/new-brunswick',
#   '/princeton',
#   '/toms-river',
#   '/vernon'],
#  'new mexico': ['/albuquerque',
#   '/aztec',
#   '/clovis',
#   '/las-cruces',
#   '/roswell',
#   '/ruidoso',
#   '/santa-fe'],
#  'new york': ['/albany',
#   '/auburn-ny',
#   '/batavia',
#   '/binghamton',
#   '/buffalo',
#   '/cooperstown',
#   '/fulton',
#   '/horseheads',
#   '/ithaca',
#   '/nyc',
#   '/newburgh',
#   '/nyack',
#   '/riverhead',
#   '/rochester',
#   '/swain',
#   '/syracuse',
#   '/ulster-park',
#   '/watertown',
#   '/white-plains',
#   '/yorktown'],
#  'north carolina': ['/archdale',
#   '/asheville',
#   '/beaufort-nc',
#   '/boone',
#   '/cameron',
#   '/charlotte',
#   '/fayetteville',
#   '/goldsboro',
#   '/greensboro',
#   '/greenville-nc',
#   '/hudson',
#   '/jacksonville-nc',
#   '/maggie-valley',
#   '/mebane',
#   '/mooresville',
#   '/morrisville',
#   '/new-bern',
#   '/raleigh',
#   '/shelby',
#   '/smithfield',
#   '/southern-pines',
#   '/southern-shores',
#   '/statesville',
#   '/sylva',
#   '/wilmington',
#   '/winston-salem'],
#  'north dakota': ['/bismarck',
#   '/west-fargo',
#   '/grand-forks',
#   '/minot',
#   '/williston'],
#  'ohio': ['/akron',
#   '/ashtabula',
#   '/bellaire',
#   '/canton',
#   '/cincinnati',
#   '/cleveland',
#   '/columbus',
#   '/dayton',
#   '/findlay',
#   '/mansfield',
#   '/portsmouth-oh',
#   '/sandusky',
#   '/toledo',
#   '/wapakoneta',
#   '/warren-oh'],
#  'oklahoma': ['/broken-bow',
#   '/durant',
#   '/lawton',
#   '/muldrow',
#   '/oklahoma-city',
#   '/tulsa'],
#  'oregon': ['/bend',
#   '/cannon-beach',
#   '/eugene',
#   '/hood-river',
#   '/la-grande',
#   '/medford',
#   '/newport',
#   '/portland',
#   '/salem'],
#  'pennsylvania': ['/annville',
#   '/bartonsville',
#   '/bethlehem',
#   '/erie',
#   '/gettysburg',
#   '/hershey',
#   '/king-of-prussia',
#   '/lancaster',
#   '/lewisburg',
#   '/montgomeryville',
#   '/philly',
#   '/pittsburgh',
#   '/scranton',
#   '/sinking-spring',
#   '/slippery-rock',
#   '/stevens',
#   '/titusville',
#   '/trappe',
#   '/wyomissing',
#   '/york'],
#  'rhode island': ['/providence'],
#  'south carolina': ['/aiken',
#   '/beaufort',
#   '/charleston',
#   '/columbia',
#   '/florence-sc',
#   '/gaffney',
#   '/greenville',
#   '/hilton-head',
#   '/myrtle-beach',
#   '/rock-hill'],
#  'south dakota': ['/rapid-city', '/sioux-falls'],
#  'tennessee': ['/chattanooga',
#   '/clarksville',
#   '/jacksoj',
#   '/kingsport',
#   '/knoxville',
#   '/memphis',
#   '/murfreesboro',
#   '/nashville',
#   '/pigeon-forge'],
#  'texas': ['/amarillo',
#   '/arlington-tx',
#   '/austin',
#   '/college-station',
#   '/corpus-christi',
#   '/dallas',
#   '/denton',
#   '/el-paso',
#   '/fredericksburg-tx',
#   '/harlingen',
#   '/houston',
#   '/killeen',
#   '/lubbock',
#   '/marathon',
#   '/mckinney',
#   '/san-antonio',
#   '/san-marcos',
#   '/sherman',
#   '/tyler',
#   '/victoria',
#   '/waco'],
#  'utah': ['/cedar-city', '/ogden', '/provo', '/slc', '/st-george'],
#  'vermont': ['/burlington', '/dover-vt', '/stowe'],
#  'virginia': ['/arlington-va',
#   '/charlottesville',
#   '/fredericksburg',
#   '/harrisonburg',
#   '/lynchburg',
#   '/newport-news',
#   '/richmond-v-a',
#   '/roanoke',
#   '/virginia-beach',
#   '/warrenton',
#   '/williamsburg'],
#  'washington': ['/gig-harbor',
#   '/marysville',
#   '/seattle',
#   '/spokane',
#   '/tacoma',
#   '/wenatchee'],
#  'west virginia': ['/charleston-wv',
#   '/fayetteville-wv',
#   '/huntington',
#   '/morgantown',
#   '/parkersburg',
#   '/princeton-wv',
#   '/weirton'],
#  'wisconsin': ['/appleton',
#   '/eau-claire',
#   '/green-bay',
#   '/la-crosse',
#   '/lake-geneva',
#   '/madison',
#   '/manitowoc',
#   '/milwaukee',
#   '/minocqua',
#   '/oshkosh',
#   '/wausau',
#   '/wisconsin-dells'],
#  'wyoming': ['/casper',
#   '/cheyenne',
#   '/cody',
#   '/evanston',
#   '/gillette',
#   '/rock-springs',
#   '/sheridan']}
